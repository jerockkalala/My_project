# %% [markdown]
# ##### Title: Exercice 4.2
# ##### Author: Jerock Kalala
# ##### Date: January 20th 2023
# ##### Modified By: --
# ##### Using Natural Language Processing (NLP)

# %% [markdown]
# 1. In the text, there’s a text normalizer created – your assignment is to re-create that normalizer as a Python class that can be re-used (within a .py file). However, unlike the book author’s version, pass a Pandas Series (e.g., dataframe[‘column’]) to your normalize_corpus function and use apply/lambda for each cleaning function.

# %%
from bs4 import BeautifulSoup
from typing import List
import  pandas as pd
import unicodedata
import re
import nltk
from nltk.corpus import gutenberg
import string
import spacy

class TextNormalizer:

    def normalize_corpus(self, corpus: pd.Series, html_stripping=True, contraction_expansion=False, accented_char_removal=True,
                     text_lower_case=True, text_lemmatization=True, special_char_removal=True,
                     stopword_removal=True, remove_digits=True) -> pd.Series:
        """
        corpus : pd.Series :  A pandas series containing text data
        html_stripping : bool :  whether or not to remove html tags from the text
        contraction_expansion : bool : whether or not to expand contractions
        accented_char_removal : bool : whether or not to remove accented characters
        text_lower_case : bool : whether or not to convert text to lowercase
        text_lemmatization : bool : whether or not to lemmatize text
        special_char_removal : bool : whether or not to remove special characters and/or digits
        stopword_removal : bool : whether or not to remove stopwords
        remove_digits : bool : whether or not to remove digits from the text
        """
        corpus = corpus.apply(lambda doc: self.strip_html_tags(doc) if html_stripping else doc)
        corpus = corpus.apply(lambda doc: self.remove_accented_chars(doc) if accented_char_removal else doc)
        corpus = corpus.apply(lambda doc: self.expand_contractions(doc) if contraction_expansion else doc)
        corpus = corpus.apply(lambda doc: doc.lower() if text_lower_case else doc)
        corpus = corpus.apply(lambda doc: re.sub(r'[\r|\n|\r\n]+', ' ', doc))
        corpus = corpus.apply(lambda doc: self.text_lemmatization(doc) if text_lemmatization else doc)
        corpus = corpus.apply(lambda doc: self.remove_special_character(doc, remove_digits) if special_char_removal else doc)
        corpus = corpus.apply(lambda doc: re.sub(' +', ' ', doc))
        corpus = corpus.apply(lambda doc: self.remove_stopwords(doc, is_lower_case=text_lower_case) if stopword_removal else doc)
        return corpus

    def strip_html_tags(self, text):
        soup = BeautifulSoup(text, "html.parser")
        [s.extract() for s in soup(['iframe', 'script'])]
        stripped_text = soup.get_text()
        stripped_text = re.sub(r'[\r|\n|\r\n]+', '\n', stripped_text)
        return stripped_text
    def remove_accented_chars(self, text):
        text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
        return text

    def text_lower_case(text):
        text_low = text.str.lower()
        return text_low

    def text_lemmatization(self, text):
        nlp = spacy.load('en_core_web_sm')
        text = nlp(text)
        text = ' '.join([word.lemma_ if word.lemma_ !='-PRON-' else word.text for word in text])
        return text

    def remove_digits(self, text):
        text = res = ''.join([i for i in text if not i.isdigit()])
        return text
    def remove_special_character(self, text, remove_digits=True):
        pattern = r'[^a-zA-z0-9\s]' if not remove_digits else r'[^a-zA-z\s]'
        text = re.sub(pattern, '', text)
        return text

    def remove_stopwords(self, text, is_lower_case=False):
        stopword_list = nltk.corpus.stopwords.words('english')
        stopword_list = set(stopword_list)
        if is_lower_case:
            text = [word for word in text.split() if word.lower() not in stopword_list]
        else:
            text = [word for word in text.split() if word not in stopword_list]
        return ' '.join(text)

# %% [markdown]
# 2. Using your new text normalizer, create a Jupyter Notebook that uses this class to clean up the text found in the file big.txt (that text file is in the GitHub for Week 4 repository). Your resulting text should be a (long) single stream of text.

# %%
# read the contents of big.txt into a pandas series
big_txt = pd.read_fwf('big.txt', header=None)
corpus = big_txt[0]
# create an instance of the TextNormalizer class
normalizer = TextNormalizer()

# normalize the big_txt series using the normalize_corpus function
big_txt_normalized = normalizer.normalize_corpus(corpus)
big_txt_normalized[:100]
# Out:
# C:\Users\jeroc\Python\Python310\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# 0      project gutenberg ebook adventure sherlock holme
# 1                                sir arthur conan doyle
# 2                         series sir arthur conan doyle
# 3                 copyright law change world sure check
# 4           copyright law country download redistribute
#                             ...
# 95                               aware say holmes dryly
# 96    circumstance great delicacy every precaution t...
# 97    also aware murmur holme settle armchair close eye
# 98    visitor glance apparent surprise languid loung...
# 99    majesty would condescend state case remark wel...
# Name: 0, Length: 100, dtype: object

# %% [markdown]
# 3. Using spaCy and NLTK, show the tokens, lemmas, parts of speech, and dependencies in the first 1,021 characters of big.txt.

# %%
import spacy

# load the spaCy model
nlp = spacy.load("en_core_web_sm")

# get the first 1021 characters of big_txt_normalized
text = big_txt_normalized[:1021]

# process the text using spaCy
doc = nlp(text.to_string())

# print the tokens, lemmas, POS tags, and dependencies
for token in doc:
    print(token.text,"*", token.lemma_, "*", token.pos_, "*", token.dep_)
# Out:
# 0 * 0 * NUM * nummod
#        *        * SPACE * dep
# project * project * NOUN * compound
# gutenberg * gutenberg * PROPN * compound
# ebook * ebook * PROPN * nsubj
# adventure * adventure * NOUN * compound
# sherlock * sherlock * NOUN * compound
# holme * holme * NOUN * appos
#
#  *
#  * SPACE * dep
# 1 * 1 * NUM * nummod
#                                  *                                  * SPACE * dep
# sir * sir * PROPN * compound
# arthur * arthur * PROPN * compound
# conan * conan * PROPN * compound
# doyle * doyle * PROPN * appos
#
#  *
#  * SPACE * dep
# 2 * 2 * NUM * nummod
#                           *                           * SPACE * dep
# series * series * NOUN * conj
# sir * sir * PROPN * compound
# arthur * arthur * PROPN * compound
# conan * conan * PROPN * compound
# doyle * doyle * PROPN * npadvmod
#
#  *
#  * SPACE * dep
# 3 * 3 * NUM * nummod
#                   *                   * SPACE * dep
# copyright * copyright * NOUN * compound
# law * law * NOUN * compound
# change * change * NOUN * compound
# world * world * NOUN * nsubj
# sure * sure * ADV * advmod
# check * check * VERB * ccomp
#
#  *
#  * SPACE * dep
# 4 * 4 * NUM * nummod
#             *             * SPACE * dep
# copyright * copyright * NOUN * compound
# law * law * NOUN * compound
# country * country * NOUN * compound
# download * download * NOUN * nsubj
# redistribute * redistribute * VERB * conj
#
#  *
#  * SPACE * dep
# 5 * 5 * NUM * nummod
#                                 *                                 * SPACE * dep
# project * project * NOUN * compound
# gutenberg * gutenberg * PROPN * dobj
# ebook * ebook * VERB * conj
#
#  *
#  * SPACE * dep
# 6 * 6 * NUM * nummod
#                     *                     * SPACE * dep
# header * header * NOUN * nmod
# first * first * ADJ * amod
# thing * thing * NOUN * nsubj
# see * see * VERB * ccomp
# view * view * NOUN * compound
# project * project * NOUN * nsubj
#
#  *
#  * SPACE * dep
# 7 * 7 * NUM * nummod
#                *                * SPACE * dep
# gutenberg * gutenberg * PROPN * compound
# file * file * NOUN * appos
# please * please * INTJ * intj
# remove * remove * VERB * ccomp
# change * change * NOUN * compound
# edit * edit * NOUN * dobj
#
#  *
#  * SPACE * dep
# 8 * 8 * NUM * nummod
#                         *                         * SPACE * dep
# header * header * NOUN * dobj
# without * without * ADP * prep
# write * write * ADJ * compound
# permission * permission * NOUN * pobj
#
#  *
#  * SPACE * dep
# 9 * 9 * NUM * nummod
#               *               * SPACE * dep
# please * please * INTJ * intj
# read * read * VERB * ccomp
# legal * legal * ADJ * amod
# small * small * ADJ * amod
# print * print * NOUN * compound
# information * information * NOUN * dobj
#
#  *
#  * SPACE * dep
# 10 * 10 * NUM * nummod
#            *            * SPACE * dep
# ebook * ebook * PROPN * compound
# project * project * NOUN * nmod
# gutenberg * gutenberg * PROPN * compound
# bottom * bottom * PROPN * compound
# file * file * NOUN * appos
# include * include * VERB * conj
#
#  *
#  * SPACE * dep
# 11 * 11 * NUM * nummod
#       *       * SPACE * dep
# important * important * ADJ * amod
# information * information * NOUN * npadvmod
# specific * specific * ADJ * dobj
# right * right * ADJ * amod
# restriction * restriction * NOUN * dobj
#
#  *
#  * SPACE * dep
# 12 * 12 * NUM * nummod
#                            *                            * SPACE * dep
# file * file * NOUN * nsubj
# may * may * AUX * aux
# use * use * AUX * aux
# also * also * ADV * advmod
# find * find * VERB * conj
# make * make * VERB * xcomp
#
#  *
#  * SPACE * dep
# 13 * 13 * NUM * nummod
#                 *                 * SPACE * dep
# donation * donation * NOUN * compound
# project * project * NOUN * compound
# gutenberg * gutenberg * PROPN * nsubj
# get * get * AUX * auxpass
# involve * involve * X * dep
#
#  *
#  * SPACE * dep
# 14 * 14 * NUM * nummod
#       *       * SPACE * dep
# welcome * welcome * ADJ * npadvmod
# world * world * NOUN * npadvmod
# free * free * ADJ * dobj
# plain * plain * ADJ * amod
# vanilla * vanilla * NOUN * nmod
# electronic * electronic * ADJ * amod
# text * text * NOUN * dobj
#
#  *
#  * SPACE * dep
# 15 * 15 * NUM * nummod
#                    *                    * SPACE * dep
# ebook * ebook * VERB * conj
# readable * readable * ADJ * amod
# human * human * ADJ * amod
# computer * computer * NOUN * dobj
# since * since * SCONJ * mark
#
#  *
#  * SPACE * dep
# 16 * 16 * NUM * nummod
#                       *                       * SPACE * dep
# ebook * ebook * PROPN * nsubj
# prepare * prepare * VERB * advcl
# thousand * thousand * NUM * nummod
# volunteer * volunteer * NOUN * nmod
#
#  *
#  * SPACE * dep
# 17 * 17 * NUM * nummod
#                         *                         * SPACE * dep
# title * title * NOUN * compound
# adventure * adventure * NOUN * compound
# sherlock * sherlock * NOUN * compound
# holme * holme * PROPN * dobj
#
#  *
#  * SPACE * dep
# 18 * 18 * NUM * nummod
#                          *                          * SPACE * dep
# author * author * NOUN * dobj
# sir * sir * PROPN * compound
# arthur * arthur * PROPN * compound
# conan * conan * PROPN * compound
# doyle * doyle * PROPN * appos
#
#  *
#  * SPACE * dep
# 19 * 19 * NUM * nummod
#                           *                           * SPACE * dep
# release * release * NOUN * compound
# date * date * NOUN * appos
# march * march * PROPN * npadvmod
# [ * [ * PUNCT * punct
# ebook * ebook * VERB * dep
# ] * ] * PUNCT * punct
#
#  *
#  * SPACE * dep
# 20 * 20 * NUM * nsubj
#                           *                           * SPACE * dep
# [ * [ * PUNCT * punct
# recently * recently * ADV * advmod
# update * update * VERB * conj
# november * november * PROPN * npadvmod
# ] * ] * PUNCT * punct
#
#  *
#  * SPACE * dep
# 21 * 21 * NUM * nummod
#                                                *                                                * SPACE * dep
# edition * edition * NOUN * npadvmod
#
#  *
#  * SPACE * dep
# 22 * 22 * NUM * nummod
#                                       *                                       * SPACE * dep
# language * language * NOUN * compound
# english * english * ADJ * appos
#
#  *
#  * SPACE * dep
# 23 * 23 * NUM * nummod
#                           *                           * SPACE * dep
# character * character * NOUN * compound
# set * set * NOUN * compound
# encoding * encode * VERB * conj
# ascii * ascii * NOUN * dobj
#
#  *
#  * SPACE * dep
# 24 * 24 * NUM * nummod
#      *      * SPACE * dep
# start * start * NOUN * compound
# project * project * NOUN * compound
# gutenberg * gutenberg * PROPN * compound
# ebook * ebook * PROPN * compound
# adventure * adventure * NOUN * compound
# sherlo * sherlo * PROPN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 25 * 25 * NUM * nummod
#                       *                       * SPACE * dep
# additional * additional * ADJ * amod
# editing * editing * NOUN * compound
# jose * jose * NOUN * dep
# menendez * menendez * PROPN * nmod
#
#  *
#  * SPACE * dep
# 26 * 26 * NUM * nummod
#                                              *                                              * SPACE * dep
# adventure * adventure * NOUN * appos
#
#  *
#  * SPACE * dep
# 27 * 27 * NUM * nummod
#                                         *                                         * SPACE * dep
# sherlock * sherlock * NOUN * compound
# holme * holme * NOUN * appos
#
#  *
#  * SPACE * dep
# 28 * 28 * NUM * compound
#
#  *
#  * SPACE * dep
# 29 * 29 * NUM * appos
#                                 *                                 * SPACE * dep
# sir * sir * PROPN * compound
# arthur * arthur * PROPN * compound
# conan * conan * PROPN * compound
# doyle * doyle * PROPN * appos
#
#  *
#  * SPACE * dep
# 30 * 30 * NUM * nummod
#                                                *                                                * SPACE * dep
# content * content * NOUN * nmod
#
#  *
#  * SPACE * dep
# 31 * 31 * NUM * nummod
#                                        *                                        * SPACE * dep
# scandal * scandal * NOUN * compound
# bohemia * bohemia * NOUN * appos
#
#  *
#  * SPACE * dep
# 32 * 32 * NUM * nummod
#                                     *                                     * SPACE * dep
# ii * ii * PROPN * compound
# red * red * ADJ * amod
# head * head * PROPN * compound
# league * league * PROPN * appos
#
#  *
#  * SPACE * dep
# 33 * 33 * NUM * compound
#                                      *                                      * SPACE * dep
# iii * iii * NUM * compound
# case * case * NOUN * compound
# identity * identity * NOUN * nsubj
#
#  *
#  * SPACE * dep
# 34 * 34 * NUM * nummod
#                             *                             * SPACE * dep
# iv * iv * PROPN * compound
# boscombe * boscombe * PROPN * compound
# valley * valley * PROPN * compound
# mystery * mystery * PROPN * appos
#
#  *
#  * SPACE * dep
# 35 * 35 * NUM * nummod
#                                      *                                      * SPACE * dep
# v * v * NOUN * compound
# five * five * NUM * nummod
# orange * orange * PROPN * compound
# pip * pip * PROPN * compound
#
#  *
#  * SPACE * dep
# 36 * 36 * NUM * nummod
#                                     *                                     * SPACE * dep
# vi * vi * NOUN * compound
# man * man * NOUN * appos
# twisted * twist * VERB * conj
# lip * lip * NOUN * dobj
#
#  *
#  * SPACE * dep
# 37 * 37 * NUM * nummod
#                           *                           * SPACE * dep
# vii * vii * PROPN * compound
# adventure * adventure * NOUN * nmod
# blue * blue * ADJ * amod
# carbuncle * carbuncle * NOUN * dobj
#
#  *
#  * SPACE * dep
# 38 * 38 * NUM * nummod
#                           *                           * SPACE * dep
# viii * viii * PROPN * compound
# adventure * adventure * NOUN * nsubj
# speckled * speckle * VERB * conj
# band * band * NOUN * dobj
#
#  *
#  * SPACE * dep
# 39 * 39 * NUM * compound
#                            *                            * SPACE * dep
# ix * ix * PROPN * compound
# adventure * adventure * NOUN * compound
# engineer * engineer * NOUN * compound
# thumb * thumb * NOUN * dobj
#
#  *
#  * SPACE * dep
# 40 * 40 * NUM * nummod
#                             *                             * SPACE * dep
# x * x * NOUN * compound
# adventure * adventure * NOUN * nmod
# noble * noble * ADJ * amod
# bachelor * bachelor * NOUN * compound
#
#  *
#  * SPACE * dep
# 41 * 41 * NUM * nummod
#                             *                             * SPACE * dep
# xi * xi * PROPN * compound
# adventure * adventure * PROPN * compound
# beryl * beryl * PROPN * compound
# coronet * coronet * NOUN * dobj
#
#  *
#  * SPACE * dep
# 42 * 42 * NUM * nummod
#                             *                             * SPACE * dep
# xii * xii * NOUN * compound
# adventure * adventure * NOUN * compound
# copper * copper * NOUN * compound
# beech * beech * NOUN * compound
#
#  *
#  * SPACE * dep
# 43 * 43 * NUM * nummod
#                              *                              * SPACE * dep
# adventure * adventure * NOUN * compound
# scandal * scandal * NOUN * compound
# bohemia * bohemia * NOUN * dobj
#
#  *
#  * SPACE * dep
# 44 * 44 * NUM * nummod
#
#  *
#  * SPACE * dep
# 45 * 45 * NUM * quantmod
#      *      * SPACE * dep
# sherlock * sherlock * NOUN * compound
# holme * holme * NOUN * npadvmod
# always * always * ADV * advmod
# woman * woman * NOUN * nsubj
# seldom * seldom * ADV * advmod
# hear * hear * VERB * ccomp
# mentio * mentio * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 46 * 46 * NUM * nsubj
#      *      * SPACE * dep
# see * see * VERB * conj
# little * little * ADJ * amod
# holme * holme * NOUN * dobj
# lately * lately * ADV * advmod
# marriage * marriage * NOUN * compound
# drift * drift * NOUN * dobj
# away * away * ADV * advmod
# co * co * NOUN * dep
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 47 * 47 * NUM * nummod
#      *      * SPACE * dep
# one * one * NUM * nummod
# night * night * NOUN * npadvmod
# twentieth * twentieth * ADJ * amod
# march * march * PROPN * compound
# return * return * NOUN * compound
# journey * journey * PROPN * compound
# patie * patie * PROPN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 48 * 48 * NUM * nummod
#      *      * SPACE * dep
# manner * manner * NOUN * npadvmod
# effusive * effusive * VERB * appos
# seldom * seldom * ADV * advmod
# glad * glad * ADJ * amod
# think * think * NOUN * appos
# see * see * VERB * acl
# hardly * hardly * ADV * advmod
# w * w * X * nmod
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 49 * 49 * NUM * nummod
#      *      * SPACE * dep
# wedlock * wedlock * NOUN * compound
# suit * suit * NOUN * compound
# remark * remark * NOUN * dobj
# think * think * VERB * conj
# watson * watson * PROPN * nsubj
# put * put * VERB * ccomp
# seven * seven * NUM * nummod
# hal * hal * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 50 * 50 * NUM * compound
#                                           *                                           * SPACE * dep
# seven * seven * NUM * nummod
# answer * answer * NOUN * npadvmod
#
#  *
#  * SPACE * dep
# 51 * 51 * NUM * nummod
#      *      * SPACE * dep
# indeed * indeed * ADV * advmod
# think * think * VERB * dep
# little * little * ADJ * amod
# trifle * trifle * ADV * nmod
# fancy * fancy * ADJ * amod
# watson * watson * PROPN * compound
# practi * practi * PROPN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 52 * 52 * NUM * dobj
#                                                   *                                                   * SPACE * dep
# know * know * VERB * conj
#
#  *
#  * SPACE * dep
# 53 * 53 * NUM * nsubj
#      *      * SPACE * dep
# see * see * VERB * ccomp
# deduce * deduce * NOUN * nsubj
# know * know * VERB * parataxis
# get * get * VERB * ccomp
# wet * wet * ADJ * amod
# lately * lately * ADV * advmod
# clumsy * clumsy * ADJ * amod
# careless * careless * NOUN * ccomp
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 54 * 54 * NUM * nummod
#      *      * SPACE * dep
# dear * dear * ADJ * amod
# holme * holme * NOUN * nsubj
# say * say * VERB * ccomp
# much * much * ADJ * nsubj
# would * would * AUX * aux
# certainly * certainly * ADV * advmod
# burn * burn * VERB * ccomp
# live * live * ADV * advmod
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 55 * 55 * NUM * nummod
#                 *                 * SPACE * dep
# chuckle * chuckle * NOUN * compound
# rub * rub * PROPN * nmod
# long * long * ADJ * amod
# nervous * nervous * ADJ * amod
# hand * hand * NOUN * npadvmod
# together * together * ADV * advmod
#
#  *
#  * SPACE * dep
# 56 * 56 * NUM * nummod
#      *      * SPACE * dep
# simplicity * simplicity * NOUN * nsubj
# say * say * VERB * ccomp
# eye * eye * NOUN * nsubj
# tell * tell * VERB * ccomp
# inside * inside * ADV * advmod
# left * left * ADJ * amod
# shoe * shoe * NOUN * compound
# firel * firel * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 57 * 57 * NUM * nsubj
#      *      * SPACE * dep
# could * could * AUX * aux
# help * help * VERB * ccomp
# laugh * laugh * VERB * xcomp
# ease * ease * NOUN * dobj
# explain * explain * VERB * xcomp
# process * process * NOUN * compound
# deductio * deductio * PROPN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 58 * 58 * NUM * nsubj
#      *      * SPACE * dep
# quite * quite * ADV * advmod
# answer * answer * VERB * ccomp
# light * light * ADJ * amod
# cigarette * cigarette * NOUN * compound
# throw * throw * NOUN * compound
# armchair * armchair * NOUN * dobj
# se * se * PROPN * advmod
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 59 * 59 * NUM * dobj
#                                             *                                             * SPACE * dep
# frequently * frequently * ADV * advmod
#
#  *
#  * SPACE * dep
# 60 * 60 * NUM * conj
#                                                  *                                                  * SPACE * dep
# often * often * ADV * advmod
#
#  *
#  * SPACE * dep
# 61 * 61 * NUM * nummod
#                                      *                                      * SPACE * dep
# well * well * ADV * advmod
# hundred * hundred * NUM * nummod
# time * time * NOUN * npadvmod
#
#  *
#  * SPACE * dep
# 62 * 62 * NUM * nummod
#                                                   *                                                   * SPACE * dep
# many * many * ADJ * amod
#
#  *
#  * SPACE * dep
# 63 * 63 * NUM * conj
#                                              *                                              * SPACE * dep
# many * many * ADJ * nsubj
# know * know * VERB * conj
#
#  *
#  * SPACE * dep
# 64 * 64 * NUM * nsubj
#      *      * SPACE * dep
# quite * quite * ADV * advmod
# observe * observe * VERB * ccomp
# yet * yet * ADV * cc
# see * see * VERB * conj
# point * point * NOUN * nsubj
# know * know * VERB * ccomp
# seventeen * seventeen * NUM * nummod
# ste * ste * NOUN * nmod
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 65 * 65 * NUM * nummod
#          *          * SPACE * dep
# note * note * NOUN * nsubj
# undated * undated * ADJ * ccomp
# without * without * ADP * prep
# either * either * CCONJ * preconj
# signature * signature * NOUN * compound
# address * address * NOUN * pobj
#
#  *
#  * SPACE * dep
# 66 * 66 * NUM * nummod
#      *      * SPACE * dep
# call * call * NOUN * appos
# upon * upon * SCONJ * prep
# night * night * NOUN * compound
# quarter * quarter * NOUN * pobj
# eight * eight * NUM * nummod
# oclock * oclock * NOUN * nsubj
# say * say * VERB * ccomp
# gentl * gentl * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 67 * 67 * NUM * nummod
#                     *                     * SPACE * dep
# indeed * indeed * ADV * advmod
# mystery * mystery * NOUN * compound
# remark * remark * NOUN * compound
# imagine * imagine * NOUN * nsubj
# mean * mean * VERB * ccomp
#
#  *
#  * SPACE * dep
# 68 * 68 * NUM * nummod
#      *      * SPACE * dep
# datum * datum * PROPN * ccomp
# yet * yet * CCONJ * cc
# capital * capital * NOUN * compound
# mistake * mistake * PROPN * conj
# theorise * theorise * ADV * advmod
# one * one * NUM * nummod
# datum * datum * PROPN * ccomp
# i * I * PRON * nsubj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 69 * 69 * NUM * nsubj
#             *             * SPACE * dep
# carefully * carefully * ADV * advmod
# examine * examine * VERB * ccomp
# writing * write * VERB * xcomp
# paper * paper * NOUN * dobj
# upon * upon * SCONJ * prep
# write * write * ADJ * amod
#
#  *
#  * SPACE * dep
# 70 * 70 * NUM * nummod
#      *      * SPACE * dep
# man * man * NOUN * pobj
# write * write * VERB * conj
# presumably * presumably * ADV * advmod
# well * well * ADV * advmod
# remark * remark * PROPN * dobj
# endeavour * endeavour * PROPN * compound
# imi * imi * PROPN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 71 * 71 * NUM * nummod
#       *       * SPACE * dep
# peculiar * peculiar * ADJ * amod
# word * word * NOUN * nsubj
# say * say * VERB * ccomp
# holme * holme * PROPN * compound
# english * english * PROPN * compound
# paper * paper * NOUN * nsubj
# hold * hold * VERB * ccomp
# light * light * ADJ * amod
#
#  *
#  * SPACE * dep
# 72 * 72 * NUM * dobj
#      *      * SPACE * dep
# see * see * VERB * ccomp
# large * large * ADJ * amod
# e * e * NOUN * compound
# small * small * ADJ * amod
# g * g * PROPN * nmod
# p * p * NOUN * nmod
# large * large * ADJ * amod
# g * g * NOUN * nmod
# small * small * ADJ * amod
# weave * weave * NOUN * compound
# text * text * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 73 * 73 * NUM * nsubj
#                                         *                                         * SPACE * dep
# make * make * VERB * ccomp
# ask * ask * VERB * csubj
# holme * holme * NOUN * dobj
#
#  *
#  * SPACE * dep
# 74 * 74 * NUM * nummod
#                       *                       * SPACE * dep
# name * name * NOUN * compound
# maker * maker * NOUN * dobj
# doubt * doubt * VERB * ccomp
# monogram * monogram * NOUN * dobj
# rather * rather * ADV * advmod
#
#  *
#  * SPACE * dep
# 75 * 75 * NUM * nummod
#      *      * SPACE * dep
# g * g * NOUN * nsubj
# small * small * ADJ * amod
# stand * stand * NOUN * compound
# gesellschaft * gesellschaft * NOUN * nmod
# german * german * ADJ * amod
# company * company * NOUN * compound
# cust * cust * NOUN * ccomp
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 76 * 76 * NUM * nummod
#                                 *                                 * SPACE * dep
# paper * paper * NOUN * nsubj
# make * make * VERB * ccomp
# bohemia * bohemia * NOUN * nsubj
# say * say * VERB * ccomp
#
#  *
#  * SPACE * dep
# 77 * 77 * NUM * nummod
#      *      * SPACE * dep
# precisely * precisely * ADV * advmod
# man * man * NOUN * nsubj
# write * write * VERB * ccomp
# note * note * VERB * xcomp
# german * german * ADJ * amod
# note * note * NOUN * nsubj
# peculiar * peculiar * ADJ * ccomp
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 78 * 78 * NUM * nsubj
#      *      * SPACE * dep
# speak * speak * VERB * ccomp
# sharp * sharp * ADJ * amod
# sound * sound * ADJ * amod
# horse * horse * NOUN * npadvmod
# hoof * hoof * ADJ * amod
# grate * grate * NOUN * compound
# wheel * wheel * NOUN * compound
# curb * curb * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 79 * 79 * NUM * nummod
#      *      * SPACE * dep
# pair * pair * NOUN * compound
# sound * sound * NOUN * nsubj
# say * say * VERB * ROOT
# yes * yes * INTJ * nsubj
# continue * continue * VERB * ccomp
# glance * glance * NOUN * compound
# window * window * NOUN * compound
# nice * nice * ADJ * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 80 * 80 * NUM * nsubj
#                                    *                                    * SPACE * dep
# think * think * VERB * conj
# well * well * INTJ * intj
# go * go * VERB * ccomp
# holme * holme * NOUN * npadvmod
#
#  *
#  * SPACE * dep
# 81 * 81 * NUM * nummod
#      *      * SPACE * dep
# bit * bit * NOUN * npadvmod
# doctor * doctor * NOUN * nsubj
# stay * stay * VERB * conj
# lose * lose * ADJ * acomp
# without * without * ADP * prep
# boswell * boswell * NOUN * compound
# promise * promise * NOUN * pobj
# i * I * PRON * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 82 * 82 * NUM * nummod
#                                                 *                                                 * SPACE * dep
# client * client * NOUN * nsubj
#
#  *
#  * SPACE * dep
# 83 * 83 * NUM * nummod
#      *      * SPACE * dep
# never * never * ADV * neg
# mind * mind * NOUN * appos
# may * may * AUX * aux
# want * want * VERB * ccomp
# help * help * NOUN * nsubj
# may * may * AUX * aux
# come * come * VERB * ccomp
# sit * sit * VERB * xcomp
# armchair * armchair * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 84 * 84 * NUM * nummod
#      *      * SPACE * dep
# slow * slow * ADJ * amod
# heavy * heavy * ADJ * amod
# step * step * NOUN * nsubj
# hear * hear * VERB * acl
# upon * upon * SCONJ * prep
# stair * stair * NOUN * compound
# passage * passage * NOUN * compound
# pause * pause * NOUN * pobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 85 * 85 * NUM * nummod
#                                         *                                         * SPACE * dep
# come * come * NOUN * appos
# say * say * VERB * ROOT
# holme * holme * NOUN * npadvmod
#
#  *
#  * SPACE * dep
# 86 * 86 * NUM * nummod
#      *      * SPACE * dep
# man * man * NOUN * nsubj
# enter * enter * VERB * ccomp
# could * could * AUX * aux
# hardly * hardly * ADV * advmod
# less * less * ADJ * advmod
# six * six * NUM * nummod
# foot * foot * NOUN * nmod
# six * six * NUM * nummod
# inch * inch * NOUN * npadvmod
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 87 * 87 * NUM * nummod
#      *      * SPACE * dep
# note * note * NOUN * nsubj
# ask * ask * VERB * ccomp
# deep * deep * ADJ * amod
# harsh * harsh * ADJ * amod
# voice * voice * NOUN * dobj
# strongly * strongly * ADV * advmod
# marked * marked * ADJ * amod
# germ * germ * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 88 * 88 * NUM * nummod
#      *      * SPACE * dep
# pray * pray * NOUN * nsubj
# take * take * VERB * ccomp
# seat * seat * NOUN * dobj
# say * say * VERB * ccomp
# holme * holme * PROPN * compound
# friend * friend * PROPN * compound
# colleague * colleague * PROPN * compound
# dr * dr * PROPN * compound
# w * w * PROPN * nsubj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 89 * 89 * NUM * nsubj
#      *      * SPACE * dep
# may * may * AUX * aux
# address * address * VERB * ccomp
# count * count * PROPN * compound
# von * von * PROPN * compound
# kramm * kramm * PROPN * compound
# bohemian * bohemian * PROPN * compound
# nobleman * nobleman * PROPN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 90 * 90 * NUM * nummod
#      *      * SPACE * dep
# rise * rise * NOUN * nsubj
# go * go * VERB * ccomp
# holme * holme * PROPN * compound
# catch * catch * NOUN * compound
# wrist * wrist * PROPN * nsubj
# push * push * VERB * advcl
# back * back * ADP * prt
# chair * chair * NOUN * dobj
# none * none * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 91 * 91 * NUM * nummod
#      *      * SPACE * dep
# count * count * NOUN * compound
# shrug * shrug * NOUN * nmod
# broad * broad * ADJ * amod
# shoulder * shoulder * NOUN * nsubj
# must * must * AUX * aux
# begin * begin * VERB * ccomp
# say * say * VERB * xcomp
# bind * bind * VERB * xcomp
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 92 * 92 * NUM * nummod
#                                      *                                      * SPACE * dep
# promise * promise * NOUN * nsubj
# say * say * VERB * ccomp
# holme * holme * NOUN * compound
#
#  *
#  * SPACE * dep
# 93 * 93 * NUM * nummod
#
#  *
#  * SPACE * dep
# 94 * 94 * NUM * nummod
#      *      * SPACE * dep
# excuse * excuse * NOUN * compound
# mask * mask * NOUN * nsubj
# continue * continue * VERB * ccomp
# strange * strange * ADJ * amod
# visitor * visitor * NOUN * compound
# august * august * PROPN * compound
# pe * pe * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 95 * 95 * NUM * nsubj
#                                 *                                 * SPACE * dep
# aware * aware * ADJ * amod
# say * say * VERB * ccomp
# holmes * holmes * PROPN * compound
# dryly * dryly * PROPN * compound
#
#  *
#  * SPACE * dep
# 96 * 96 * NUM * nummod
#      *      * SPACE * dep
# circumstance * circumstance * NOUN * nmod
# great * great * ADJ * amod
# delicacy * delicacy * NOUN * dative
# every * every * DET * det
# precaution * precaution * NOUN * compound
# t * t * X * appos
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 97 * 97 * NUM * nsubj
#      *      * SPACE * dep
# also * also * ADV * advmod
# aware * aware * ADJ * nsubj
# murmur * murmur * ADJ * amod
# holme * holme * PROPN * nsubj
# settle * settle * VERB * ccomp
# armchair * armchair * NOUN * compound
# close * close * ADJ * amod
# eye * eye * NOUN * compound
#
#  *
#  * SPACE * dep
# 98 * 98 * NUM * nummod
#      *      * SPACE * dep
# visitor * visitor * NOUN * compound
# glance * glance * NOUN * dobj
# apparent * apparent * ADJ * amod
# surprise * surprise * NOUN * compound
# languid * languid * PROPN * amod
# loung * loung * ADJ * advcl
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 99 * 99 * NUM * nummod
#      *      * SPACE * dep
# majesty * majesty * PROPN * nsubj
# would * would * AUX * aux
# condescend * condescend * VERB * ccomp
# state * state * NOUN * compound
# case * case * NOUN * compound
# remark * remark * NOUN * dobj
# wel * wel * PROPN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 100 * 100 * NUM * nummod
#     *     * SPACE * dep
# man * man * NOUN * compound
# spring * spring * NOUN * compound
# chair * chair * NOUN * compound
# pace * pace * NOUN * compound
# room * room * NOUN * npadvmod
# uncontrollable * uncontrollable * ADJ * ccomp
# agit * agit * ADJ * advmod
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 101 * 101 * NUM * dobj
#     *     * SPACE * dep
# indeed * indeed * ADV * advmod
# murmur * murmur * ADJ * amod
# holme * holme * PROPN * compound
# majesty * majesty * PROPN * nsubj
# speak * speak * VERB * ccomp
# aware * aware * ADJ * amod
# addres * addre * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 102 * 102 * NUM * nummod
#     *     * SPACE * dep
# understand * understand * NOUN * nsubj
# say * say * VERB * ROOT
# strange * strange * ADJ * amod
# visitor * visitor * NOUN * compound
# sit * sit * NOUN * nsubj
# pass * pass * VERB * ccomp
# hand * hand * NOUN * compound
# h * h * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 103 * 103 * NUM * nummod
#                       *                       * SPACE * dep
# pray * pray * NOUN * compound
# consult * consult * NOUN * nsubj
# say * say * VERB * ccomp
# holme * holme * NOUN * nsubj
# shut * shut * VERB * ccomp
# eye * eye * NOUN * dobj
#
#  *
#  * SPACE * dep
# 104 * 104 * NUM * compound
#     *     * SPACE * dep
# fact * fact * NOUN * dobj
# briefly * briefly * ADV * advmod
# five * five * NUM * nummod
# year * year * NOUN * npadvmod
# ago * ago * ADV * advmod
# lengthy * lengthy * ADJ * amod
# visit * visit * NOUN * compound
# warsa * warsa * NOUN * pobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 105 * 105 * NUM * nsubj
#     *     * SPACE * dep
# kindly * kindly * ADV * advmod
# look * look * VERB * ccomp
# index * index * NOUN * compound
# doctor * doctor * NOUN * dobj
# murmur * murmur * PROPN * amod
# holme * holme * PROPN * appos
# without * without * ADP * prep
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 106 * 106 * NUM * pobj
#     *     * SPACE * dep
# let * let * VERB * conj
# see * see * VERB * nsubj
# say * say * VERB * ccomp
# holmes * holmes * PROPN * compound
# hum * hum * PROPN * nsubj
# bear * bear * PROPN * ccomp
# new * new * PROPN * compound
# jersey * jersey * PROPN * compound
# year * year * PROPN * compound
# co * co * NOUN * nsubj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 107 * 107 * NUM * nummod
#                                             *                                             * SPACE * dep
# precisely * precisely * ADV * advmod
#
#  *
#  * SPACE * dep
# 108 * 108 * NUM * nummod
#                                       *                                       * SPACE * dep
# secret * secret * ADJ * amod
# marriage * marriage * NOUN * nsubj
#
#  *
#  * SPACE * dep
# 109 * 109 * NUM * nummod
#                                                  *                                                  * SPACE * dep
# none * none * NOUN * npadvmod
#
#  *
#  * SPACE * dep
# 110 * 110 * NUM * nummod
#                               *                               * SPACE * dep
# legal * legal * ADJ * amod
# paper * paper * NOUN * compound
# certificate * certificate * NOUN * appos
#
#  *
#  * SPACE * dep
# 111 * 111 * NUM * nummod
#                                                  *                                                  * SPACE * dep
# none * none * NOUN * npadvmod
#
#  *
#  * SPACE * dep
# 112 * 112 * NUM * nummod
#     *     * SPACE * dep
# fail * fail * NOUN * appos
# follow * follow * VERB * appos
# majesty * majesty * ADJ * amod
# young * young * ADJ * amod
# person * person * NOUN * dobj
# produce * produce * VERB * conj
# lette * lette * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 113 * 113 * NUM * nummod
#                                               *                                               * SPACE * dep
# writing * write * VERB * conj
#
#  *
#  * SPACE * dep
# 114 * 114 * NUM * nummod
#                                     *                                     * SPACE * dep
# pooh * pooh * NOUN * compound
# pooh * pooh * PROPN * compound
# forgery * forgery * NOUN * compound
#
#  *
#  * SPACE * dep
# 115 * 115 * NUM * nummod
#                                    *                                    * SPACE * dep
# private * private * ADJ * amod
# note * note * NOUN * compound
# paper * paper * NOUN * dobj
#
#  *
#  * SPACE * dep
# 116 * 116 * NUM * nummod
#                                                 *                                                 * SPACE * dep
# steal * steal * NOUN * nmod
#
#  *
#  * SPACE * dep
# 117 * 117 * NUM * nummod
#                                                  *                                                  * SPACE * dep
# seal * seal * NOUN * npadvmod
#
#  *
#  * SPACE * dep
# 118 * 118 * NUM * nummod
#                                               *                                               * SPACE * dep
# imitate * imitate * VERB * conj
#
#  *
#  * SPACE * dep
# 119 * 119 * NUM * nummod
#                                            *                                            * SPACE * dep
# photograph * photograph * NOUN * dobj
#
#  *
#  * SPACE * dep
# 120 * 120 * NUM * nummod
#                                                   *                                                   * SPACE * dep
# buy * buy * VERB * compound
#
#  *
#  * SPACE * dep
# 121 * 121 * NUM * nummod
#                                            *                                            * SPACE * dep
# photograph * photograph * NOUN * conj
#
#  *
#  * SPACE * dep
# 122 * 122 * NUM * nummod
#        *        * SPACE * dep
# oh * oh * INTJ * intj
# dear * dear * ADJ * amod
# bad * bad * ADJ * amod
# majesty * majesty * NOUN * nsubj
# indeed * indeed * ADV * advmod
# commit * commit * VERB * ccomp
# indiscretion * indiscretion * NOUN * dobj
#
#  *
#  * SPACE * dep
# 123 * 123 * NUM * nummod
#                                            *                                            * SPACE * dep
# mad * mad * ADJ * amod
# insane * insane * ADJ * nmod
#
#  *
#  * SPACE * dep
# 124 * 124 * NUM * nummod
#                                  *                                  * SPACE * dep
# compromise * compromise * NOUN * dobj
# seriously * seriously * ADV * advmod
#
#  *
#  * SPACE * dep
# 125 * 125 * NUM * nummod
#                             *                             * SPACE * dep
# crown * crown * NOUN * compound
# prince * prince * NOUN * nsubj
# young * young * ADJ * amod
# thirty * thirty * NUM * compound
#
#  *
#  * SPACE * dep
# 126 * 126 * NUM * appos
#                                          *                                          * SPACE * dep
# must * must * AUX * aux
# recover * recover * VERB * conj
#
#  *
#  * SPACE * dep
# 127 * 127 * NUM * dobj
#                                              *                                              * SPACE * dep
# try * try * VERB * conj
# fail * fail * VERB * dobj
#
#  *
#  * SPACE * dep
# 128 * 128 * NUM * nummod
#                             *                             * SPACE * dep
# majesty * majesty * PROPN * nsubj
# must * must * AUX * aux
# pay * pay * VERB * relcl
# must * must * AUX * aux
# buy * buy * VERB * conj
#
#  *
#  * SPACE * dep
# 129 * 129 * NUM * nummod
#                                                  *                                                  * SPACE * dep
# sell * sell * NOUN * nmod
#
#  *
#  * SPACE * dep
# 130 * 130 * NUM * nummod
#                                                 *                                                 * SPACE * dep
# steal * steal * NOUN * dobj
#
#  *
#  * SPACE * dep
# 131 * 131 * NUM * compound
#     *     * SPACE * dep
# five * five * NUM * nummod
# attempt * attempt * NOUN * dobj
# make * make * VERB * conj
# twice * twice * PRON * amod
# burglar * burglar * NOUN * compound
# pay * pay * NOUN * compound
# ransack * ransack * NOUN * compound
# ho * ho * PROPN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 132 * 132 * NUM * nummod
#                                                  *                                                  * SPACE * dep
# sign * sign * NOUN * nsubj
#
#  *
#  * SPACE * dep
# 133 * 133 * NUM * nummod
#                                       *                                       * SPACE * dep
# absolutely * absolutely * ADV * advmod
# none * none * NOUN * appos
#
#  *
#  * SPACE * dep
# 134 * 134 * NUM * nummod
#           *           * SPACE * dep
# holme * holme * PROPN * appos
# laugh * laugh * VERB * ccomp
# quite * quite * ADV * advmod
# pretty * pretty * ADV * advmod
# little * little * ADJ * amod
# problem * problem * NOUN * dobj
# say * say * VERB * ROOT
#
#  *
#  * SPACE * dep
# 135 * 135 * NUM * nummod
#                 *                 * SPACE * dep
# serious * serious * ADJ * amod
# one * one * NUM * nummod
# return * return * NOUN * compound
# king * king * NOUN * ccomp
# reproachfully * reproachfully * ADV * advmod
#
#  *
#  * SPACE * dep
# 136 * 136 * NUM * nsubj
#                             *                             * SPACE * dep
# indeed * indeed * ADV * advmod
# propose * propose * VERB * ccomp
# photograph * photograph * NOUN * dobj
#
#  *
#  * SPACE * dep
# 137 * 137 * NUM * nummod
#                                                  *                                                  * SPACE * dep
# ruin * ruin * NOUN * dobj
#
#  *
#  * SPACE * dep
# 138 * 138 * NUM * compound
#
#  *
#  * SPACE * dep
# 139 * 139 * NUM * nummod
#                                                 *                                                 * SPACE * dep
# marry * marry * VERB * conj
#
#  *
#  * SPACE * dep
# 140 * 140 * NUM * nsubj
#                                                  *                                                  * SPACE * dep
# hear * hear * VERB * conj
#
#  *
#  * SPACE * dep
# 141 * 141 * NUM * nummod
#     *     * SPACE * dep
# clotilde * clotilde * PROPN * compound
# lothman * lothman * PROPN * compound
# von * von * PROPN * compound
# saxe * saxe * PROPN * compound
# meningen * meningen * PROPN * nmod
# second * second * PROPN * amod
# daug * daug * PROPN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 142 * 142 * NUM * nsubj
#                                           *                                           * SPACE * dep
# irene * irene * VERB * ROOT
# adler * adler * NOUN * dobj
#
#  *
#  * SPACE * dep
# 143 * 143 * NUM * npadvmod
#     *     * SPACE * dep
# threaten * threaten * VERB * conj
# send * send * VERB * conj
# photograph * photograph * NOUN * dobj
# know * know * PROPN * compound
# know * know * PROPN * dep
# soul * soul * NOUN * compound
# steel * steel * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 144 * 144 * NUM * meta
#                                         *                                         * SPACE * dep
# sure * sure * ADV * amod
# send * send * VERB * ROOT
# yet * yet * ADV * advmod
#
#  *
#  * SPACE * dep
# 145 * 145 * NUM * dobj
#                                                  *                                                  * SPACE * dep
# sure * sure * ADJ * conj
#
#  *
#  * SPACE * dep
# 146 * 146 * NUM * nummod
#
#  *
#  * SPACE * dep
# 147 * 147 * NUM * dobj
#     *     * SPACE * dep
# say * say * VERB * conj
# would * would * AUX * aux
# send * send * VERB * ccomp
# day * day * NOUN * compound
# betrothal * betrothal * NOUN * dobj
# publicly * publicly * ADV * advmod
# proclaim * proclaim * VERB * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 148 * 148 * NUM * nsubj
#     *     * SPACE * dep
# oh * oh * NUM * intj
# three * three * NUM * nummod
# day * day * NOUN * npadvmod
# yet * yet * ADV * advmod
# say * say * VERB * ccomp
# holme * holme * NOUN * compound
# yawn * yawn * NOUN * nsubj
# fortunate * fortunate * VERB * ccomp
# one * one * NUM * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 149 * 149 * NUM * nsubj
#           *           * SPACE * dep
# certainly * certainly * ADV * advmod
# find * find * VERB * conj
# langham * langham * PROPN * compound
# name * name * PROPN * compound
# count * count * PROPN * compound
# von * von * PROPN * compound
# kramm * kramm * PROPN * nsubj
#
#  *
#  * SPACE * dep
# 150 * 150 * NUM * nummod
#                     *                     * SPACE * dep
# shall * shall * AUX * aux
# drop * drop * VERB * ccomp
# line * line * NOUN * dobj
# let * let * AUX * aux
# know * know * VERB * dep
# progress * progress * VERB * ccomp
#
#  *
#  * SPACE * dep
# 151 * 151 * NUM * nummod
#                                    *                                    * SPACE * dep
# pray * pray * NOUN * nsubj
# shall * shall * AUX * aux
# anxiety * anxiety * VERB * ccomp
#
#  *
#  * SPACE * dep
# 152 * 152 * NUM * nummod
#                                                 *                                                 * SPACE * dep
# money * money * NOUN * compound
#
#  *
#  * SPACE * dep
# 153 * 153 * NUM * nummod
#                                         *                                         * SPACE * dep
# carte * carte * NOUN * compound
# blanche * blanche * NOUN * compound
#
#  *
#  * SPACE * dep
# 154 * 154 * NUM * nummod
#                                            *                                            * SPACE * dep
# absolutely * absolutely * ADV * advmod
#
#  *
#  * SPACE * dep
# 155 * 155 * NUM * nummod
#       *       * SPACE * dep
# tell * tell * NOUN * dobj
# would * would * AUX * aux
# give * give * VERB * conj
# one * one * NUM * nummod
# province * province * NOUN * compound
# kingdom * kingdom * NOUN * compound
# photograph * photograph * NOUN * dobj
#
#  *
#  * SPACE * dep
# 156 * 156 * NUM * nummod
#                                       *                                       * SPACE * dep
# present * present * ADJ * amod
# expense * expense * NOUN * npadvmod
#
#  *
#  * SPACE * dep
# 157 * 157 * NUM * nummod
#     *     * SPACE * dep
# king * king * NOUN * nsubj
# take * take * VERB * conj
# heavy * heavy * ADJ * amod
# chamois * chamois * NOUN * compound
# leather * leather * NOUN * compound
# bag * bag * NOUN * compound
# cloak * cloak * NOUN * nsubj
# lay * lie * VERB * ccomp
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 158 * 158 * NUM * compound
#       *       * SPACE * dep
# three * three * NUM * compound
# hundred * hundred * NUM * nummod
# pound * pound * NOUN * compound
# gold * gold * NOUN * dobj
# seven * seven * NUM * compound
# hundred * hundred * NUM * nummod
# note * note * NOUN * nsubj
# say * say * VERB * conj
#
#  *
#  * SPACE * dep
# 159 * 159 * NUM * nummod
#      *      * SPACE * dep
# holme * holme * NOUN * dobj
# scribble * scribble * ADJ * amod
# receipt * receipt * NOUN * ccomp
# upon * upon * SCONJ * prep
# sheet * sheet * NOUN * compound
# note * note * NOUN * compound
# book * book * NOUN * compound
# hand * hand * NOUN * compound
#
#  *
#  * SPACE * dep
# 160 * 160 * NUM * nummod
#                              *                              * SPACE * dep
# mademoiselle * mademoiselle * PROPN * compound
# address * address * NOUN * pobj
# ask * ask * VERB * ccomp
#
#  *
#  * SPACE * dep
# 161 * 161 * NUM * nummod
#           *           * SPACE * dep
# briony * briony * NOUN * compound
# lodge * lodge * PROPN * compound
# serpentine * serpentine * PROPN * compound
# avenue * avenue * PROPN * compound
# st * st * PROPN * compound
# john * john * PROPN * compound
# wood * wood * PROPN * dobj
#
#  *
#  * SPACE * dep
# 162 * 162 * NUM * nummod
#     *     * SPACE * dep
# holme * holme * PROPN * nsubj
# take * take * VERB * conj
# note * note * NOUN * dobj
# one * one * NUM * nummod
# question * question * NOUN * nsubj
# say * say * VERB * ROOT
# photograph * photograph * NOUN * compound
# ca * ca * NOUN * nsubj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 163 * 163 * NUM * nummod
#
#  *
#  * SPACE * dep
# 164 * 164 * NUM * nummod
#     *     * SPACE * dep
# good * good * ADJ * amod
# night * night * NOUN * compound
# majesty * majesty * PROPN * compound
# trust * trust * PROPN * nsubj
# shall * shall * AUX * ccomp
# soon * soon * ADV * advmod
# good * good * ADJ * amod
# news * news * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 165 * 165 * NUM * nummod
#                                                    *                                                    * SPACE * dep
# ii * ii * NOUN * conj
#
#  *
#  * SPACE * dep
# 166 * 166 * NUM * compound
#     *     * SPACE * dep
# three * three * NUM * appos
# oclock * oclock * VERB * appos
# precisely * precisely * ADV * advmod
# baker * baker * PROPN * compound
# street * street * NOUN * compound
# holme * holme * PROPN * dobj
# yet * yet * ADV * advmod
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 167 * 167 * NUM * quantmod
#     *     * SPACE * dep
# close * close * ADJ * amod
# upon * upon * SCONJ * quantmod
# four * four * NUM * nummod
# door * door * NOUN * npadvmod
# open * open * ADJ * amod
# drunken * drunken * ADJ * advmod
# look * look * VERB * ccomp
# groom * groom * PROPN * npadvmod
# i * I * PRON * intj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 168 * 168 * NUM * nsubj
#     *     * SPACE * dep
# well * well * INTJ * intj
# really * really * ADV * advmod
# cry * cry * VERB * ccomp
# choke * choke * PROPN * compound
# laugh * laugh * NOUN * compound
# oblige * oblige * PROPN * nsubj
# lie * lie * VERB * dobj
# back * back * ADV * advmod
# li * li * PROPN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 169 * 169 * NUM * compound
#
#  *
#  * SPACE * dep
# 170 * 170 * NUM * nsubj
#     *     * SPACE * dep
# quite * quite * ADV * advmod
# funny * funny * ADJ * amod
# sure * sure * ADJ * advmod
# could * could * AUX * aux
# never * never * ADV * neg
# guess * guess * VERB * ccomp
# employ * employ * PROPN * compound
# morn * morn * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 171 * 171 * NUM * nummod
#     *     * SPACE * dep
# imagine * imagine * NOUN * nsubj
# suppose * suppose * VERB * ROOT
# watch * watch * NOUN * nsubj
# habit * habit * NOUN * ccomp
# perhaps * perhaps * ADV * advmod
# house * house * NOUN * compound
# miss * miss * PROPN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 172 * 172 * NUM * nsubj
#     *     * SPACE * dep
# quite * quite * ADV * advmod
# sequel * sequel * VERB * ccomp
# rather * rather * ADV * advmod
# unusual * unusual * ADJ * amod
# tell * tell * NOUN * dobj
# however * however * ADV * advmod
# leave * leave * VERB * acl
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 173 * 173 * NUM * nummod
#     *     * SPACE * dep
# lounge * lounge * NOUN * compound
# street * street * PROPN * compound
# find * find * NOUN * nsubj
# expect * expect * VERB * ccomp
# mew * mew * DET * det
# lane * lane * NOUN * nsubj
# run * run * VERB * ccomp
# one * one * NUM * nummod
# wal * wal * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 174 * 174 * NUM * nummod
#                                       *                                       * SPACE * dep
# irene * irene * PROPN * parataxis
# adler * adler * NOUN * dobj
# ask * ask * VERB * ROOT
#
#  *
#  * SPACE * dep
# 175 * 175 * NUM * nummod
#     *     * SPACE * dep
# oh * oh * INTJ * intj
# turn * turn * VERB * compound
# man * man * NOUN * compound
# head * head * NOUN * compound
# part * part * NOUN * compound
# dainty * dainty * NOUN * compound
# thing * thing * NOUN * compound
# bonnet * bonnet * NOUN * compound
# plan * plan * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 176 * 176 * NUM * nsubj
#     *     * SPACE * dep
# godfrey * godfrey * NOUN * compound
# norton * norton * PROPN * dobj
# evidently * evidently * ADV * advmod
# important * important * ADJ * amod
# factor * factor * NOUN * compound
# matt * matt * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 177 * 177 * NUM * nummod
#                                 *                                 * SPACE * dep
# follow * follow * AUX * aux
# closely * closely * ADV * advmod
# answer * answer * VERB * ccomp
#
#  *
#  * SPACE * dep
# 178 * 178 * NUM * nummod
#     *     * SPACE * dep
# still * still * ADV * advmod
# balance * balance * NOUN * compound
# matter * matter * NOUN * compound
# mind * mind * PROPN * dobj
# hansom * hansom * PROPN * compound
# cab * cab * PROPN * compound
# drive * drive * PROPN * compound
# bri * bri * PROPN * npadvmod
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 179 * 179 * NUM * nummod
#     *     * SPACE * dep
# house * house * NOUN * nsubj
# half * half * ADJ * amod
# hour * hour * NOUN * npadvmod
# could * could * AUX * aux
# catch * catch * VERB * ccomp
# glimpse * glimpse * NOUN * compound
# window * window * NOUN * compound
# sit * sit * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 180 * 180 * NUM * nsubj
#     *     * SPACE * dep
# away * away * ADV * advmod
# go * go * VERB * xcomp
# wonder * wonder * NOUN * dep
# whether * whether * SCONJ * mark
# well * well * ADV * advmod
# follow * follow * VERB * ccomp
# lane * lane * NOUN * nsubj
# come * come * VERB * ccomp
# n * n * ADV * cc
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 181 * 181 * NUM * nummod
#     *     * SPACE * dep
# church * church * PROPN * compound
# st * st * PROPN * compound
# monica * monica * PROPN * compound
# john * john * PROPN * nsubj
# cry * cry * VERB * conj
# half * half * ADJ * amod
# sovereign * sovereign * ADJ * amod
# reach * reach * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 182 * 182 * NUM * nummod
#     *     * SPACE * dep
# quite * quite * ADV * advmod
# good * good * ADJ * amod
# lose * lose * ADJ * amod
# watson * watson * NOUN * compound
# balance * balance * NOUN * nsubj
# whether * whether * SCONJ * mark
# run * run * VERB * compound
# whe * whe * NOUN * appos
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 183 * 183 * NUM * nummod
#     *     * SPACE * dep
# cabby * cabby * PROPN * compound
# drive * drive * NOUN * nsubj
# fast * fast * ADV * advmod
# think * think * VERB * ROOT
# ever * ever * ADV * advmod
# drive * drive * VERB * ccomp
# fast * fast * ADJ * amod
# cab * cab * PROPN * compound
# lan * lan * PROPN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 184 * 184 * NUM * nummod
#                               *                               * SPACE * dep
# thank * thank * VERB * nsubj
# god * god * PROPN * dobj
# cry * cry * VERB * ccomp
# ...
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 785 * 785 * NUM * nsubj
#                          *                          * SPACE * dep
# indeed * indeed * ADV * advmod
# interesting * interesting * ADJ * amod
# say * say * VERB * ccomp
# holme * holme * NOUN * dobj
#
#  *
#  * SPACE * dep
# 786 * 786 * NUM * nummod
#      *      * SPACE * dep
# oh * oh * INTJ * intj
# yes * yes * INTJ * intj
# hundred * hundred * NUM * nummod
# way * way * NOUN * npadvmod
# help * help * VERB * ccomp
# everybody * everybody * PRON * nsubj
# speak * speak * VERB * ccomp
# kindness * kindness * NOUN * dobj
#
#  *
#  * SPACE * dep
# 787 * 787 * NUM * nummod
#     *     * SPACE * dep
# really * really * ADV * advmod
# strike * strike * VERB * conj
# little * little * ADJ * amod
# singular * singular * ADJ * amod
# mccarthy * mccarthy * NOUN * nsubj
# appear * appear * VERB * ccomp
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 788 * 788 * NUM * nsubj
#     *     * SPACE * dep
# get * get * VERB * conj
# deduction * deduction * NOUN * compound
# inference * inference * NOUN * dobj
# say * say * VERB * nmod
# lestrade * lestrade * PROPN * compound
# wink * wink * NOUN * compound
# find * find * VERB * ccomp
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 789 * 789 * NUM * nummod
#        *        * SPACE * dep
# right * right * NOUN * nsubj
# say * say * VERB * ccomp
# holme * holme * NOUN * nsubj
# demurely * demurely * ADV * advmod
# find * find * VERB * ccomp
# hard * hard * ADJ * amod
# tackle * tackle * NOUN * compound
# fact * fact * NOUN * dobj
#
#  *
#  * SPACE * dep
# 790 * 790 * NUM * nummod
#     *     * SPACE * dep
# anyhow * anyhow * ADV * advmod
# grasp * grasp * NOUN * dobj
# one * one * NUM * nummod
# fact * fact * NOUN * dobj
# seem * seem * VERB * conj
# find * find * VERB * xcomp
# difficult * difficult * ADJ * ccomp
# get * get * VERB * nsubj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 791 * 791 * NUM * nummod
#
#  *
#  * SPACE * dep
# 792 * 792 * NUM * nummod
#     *     * SPACE * dep
# mccarthy * mccarthy * NOUN * npadvmod
# senior * senior * ADJ * nsubj
# meet * meet * VERB * ccomp
# death * death * NOUN * compound
# mccarthy * mccarthy * NOUN * dobj
# junior * junior * VERB * ccomp
# the * the * DET * det
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 793 * 793 * NUM * nummod
#     *     * SPACE * dep
# well * well * INTJ * compound
# moonshine * moonshine * ADJ * amod
# bright * bright * ADJ * amod
# thing * thing * NOUN * compound
# fog * fog * PROPN * nsubj
# say * say * VERB * ROOT
# holme * holme * PROPN * compound
# laug * laug * PROPN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 794 * 794 * NUM * nummod
#     *     * SPACE * dep
# yes * yes * INTJ * npadvmod
# widespread * widespread * ADJ * advmod
# comfortable * comfortable * ADJ * amod
# look * look * NOUN * nsubj
# building * build * VERB * advcl
# two * two * NUM * nummod
# s * s * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 795 * 795 * NUM * nummod
#     *     * SPACE * dep
# sherlock * sherlock * NOUN * compound
# holme * holme * NOUN * compound
# transform * transform * NOUN * dobj
# hot * hot * ADJ * amod
# upon * upon * SCONJ * prep
# scent * scent * NOUN * compound
# man * man * PROPN * compound
# kn * kn * PROPN * pobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 796 * 796 * NUM * nummod
#     *     * SPACE * dep
# boscombe * boscombe * NOUN * compound
# pool * pool * PROPN * npadvmod
# little * little * ADJ * amod
# reed * reed * NOUN * compound
# girt * girt * NOUN * compound
# sheet * sheet * NOUN * compound
# water * water * NOUN * compound
# fif * fif * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 797 * 797 * NUM * nummod
#                                           *                                           * SPACE * dep
# go * go * VERB * dep
# pool * pool * NOUN * dobj
# ask * ask * VERB * ROOT
#
#  *
#  * SPACE * dep
# 798 * 798 * NUM * nummod
#              *              * SPACE * dep
# fish * fish * NOUN * compound
# rake * rake * NOUN * compound
# think * think * VERB * ccomp
# might * might * AUX * aux
# weapon * weapon * VERB * ccomp
# trace * trace * NOUN * compound
# earth * earth * NOUN * dobj
#
#  *
#  * SPACE * dep
# 799 * 799 * NUM * ROOT
#     *     * SPACE * dep
# oh * oh * INTJ * intj
# tut * tut * PROPN * dep
# tut * tut * DET * det
# time * time * NOUN * compound
# leave * leave * NOUN * compound
# foot * foot * NOUN * appos
# inward * inward * ADP * prep
# twist * twist * NOUN * compound
# place * place * NOUN * pobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 800 * 800 * NUM * nummod
#     *     * SPACE * dep
# case * case * NOUN * nmod
# considerable * considerable * ADJ * amod
# interest * interest * NOUN * compound
# remark * remark * NOUN * nsubj
# return * return * VERB * compound
# natur * natur * PROPN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 801 * 801 * NUM * compound
#     *     * SPACE * dep
# ten * ten * NUM * nummod
# minute * minute * NOUN * compound
# regain * regain * PROPN * compound
# cab * cab * NOUN * compound
# drive * drive * NOUN * nmod
# back * back * ADP * advmod
# ross * ross * PROPN * dobj
# holme * holme * PROPN * compound
# st * st * PROPN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 802 * 802 * NUM * nummod
#              *              * SPACE * dep
# may * may * AUX * aux
# interest * interest * NOUN * compound
# lestrade * lestrade * NOUN * compound
# remark * remark * NOUN * nsubj
# hold * hold * VERB * ccomp
# murder * murder * NOUN * dobj
#
#  *
#  * SPACE * dep
# 803 * 803 * NUM * nummod
#                                              *                                              * SPACE * dep
# see * see * VERB * conj
# mark * mark * ADJ * dobj
#
#  *
#  * SPACE * dep
# 804 * 804 * NUM * nummod
#                                                  *                                                  * SPACE * dep
# none * none * NOUN * npadvmod
#
#  *
#  * SPACE * dep
# 805 * 805 * NUM * dobj
#                                                  *                                                  * SPACE * dep
# know * know * VERB * amod
#
#  *
#  * SPACE * dep
# 806 * 806 * NUM * nummod
#     *     * SPACE * dep
# grass * grass * NOUN * nsubj
# grow * grow * VERB * conj
# lain * lain * ADJ * amod
# day * day * NOUN * compound
# sign * sign * NOUN * compound
# place * place * NOUN * dobj
# whence * whence * AUX * aux
# take * take * VERB * relcl
# cor * cor * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 807 * 807 * NUM * nummod
#                                              *                                              * SPACE * dep
# murderer * murderer * NOUN * nsubj
#
#  *
#  * SPACE * dep
# 808 * 808 * NUM * nummod
#     *     * SPACE * dep
# tall * tall * ADJ * amod
# man * man * NOUN * appos
# left * leave * VERB * acl
# handed * hand * VERB * ccomp
# limp * limp * ADJ * amod
# right * right * ADJ * amod
# leg * leg * NOUN * dobj
# wear * wear * VERB * conj
# thick * thick * ADV * advmod
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 809 * 809 * NUM * nummod
#     *     * SPACE * dep
# lestrade * lestrade * PROPN * compound
# laugh * laugh * NOUN * nsubj
# afraid * afraid * ADJ * amod
# still * still * ADV * advmod
# sceptic * sceptic * ADJ * ccomp
# say * say * VERB * ccomp
# theory * theory * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 810 * 810 * NUM * nummod
#     *     * SPACE * dep
# nous * nous * ADJ * amod
# verron * verron * PROPN * compound
# answer * answer * NOUN * compound
# holme * holme * PROPN * nsubj
# calmly * calmly * ADV * advmod
# work * work * VERB * compound
# method * method * PROPN * compound
# sh * sh * PROPN * ccomp
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 811 * 811 * NUM * nummod
#                                 *                                 * SPACE * dep
# leave * leave * NOUN * compound
# case * case * NOUN * nsubj
# unfinished * unfinishe * VERB * acl
#
#  *
#  * SPACE * dep
# 812 * 812 * NUM * dobj
#                                                *                                                * SPACE * dep
# finish * finish * NOUN * ccomp
#
#  *
#  * SPACE * dep
# 813 * 813 * NUM * nummod
#                                               *                                               * SPACE * dep
# mystery * mystery * NOUN * dobj
#
#  *
#  * SPACE * dep
# 814 * 814 * NUM * nummod
#                                                 *                                                 * SPACE * dep
# solve * solve * VERB * conj
#
#  *
#  * SPACE * dep
# 815 * 815 * NUM * nummod
#                                              *                                              * SPACE * dep
# criminal * criminal * NOUN * dobj
#
#  *
#  * SPACE * dep
# 816 * 816 * NUM * nummod
#                                    *                                    * SPACE * dep
# gentleman * gentleman * NOUN * compound
# describe * describe * VERB * conj
#
#  *
#  * SPACE * dep
# 817 * 817 * NUM * compound
#
#  *
#  * SPACE * dep
# 818 * 818 * NUM * dobj
#     *     * SPACE * dep
# surely * surely * ADV * advmod
# would * would * AUX * aux
# difficult * difficult * ADJ * ccomp
# find * find * VERB * ccomp
# populous * populous * ADJ * amod
# neighbour * neighbour * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 819 * 819 * NUM * nummod
#     *     * SPACE * dep
# lestrade * lestrade * ADJ * amod
# shrug * shrug * PROPN * compound
# shoulder * shoulder * NOUN * nmod
# practical * practical * ADJ * amod
# man * man * NOUN * nsubj
# say * say * VERB * ccomp
# real * real * ADJ * ccomp
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 820 * 820 * NUM * nummod
#     *     * SPACE * dep
# right * right * NOUN * nsubj
# say * say * VERB * ccomp
# holme * holme * PROPN * nsubj
# quietly * quietly * ADV * advmod
# give * give * VERB * ccomp
# chance * chance * NOUN * dobj
# lodging * lodge * VERB * acl
# go * go * VERB * xcomp
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 821 * 821 * NUM * nummod
#     *     * SPACE * dep
# leave * leave * VERB * ccomp
# lestrade * lestrade * ADJ * compound
# room * room * NOUN * compound
# drive * drive * NOUN * compound
# hotel * hotel * NOUN * nsubj
# find * find * VERB * ccomp
# lunch * lunch * NOUN * compound
# upo * upo * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 822 * 822 * NUM * dobj
#     *     * SPACE * dep
# look * look * PROPN * compound
# watson * watson * PROPN * nsubj
# say * say * VERB * ROOT
# cloth * cloth * PROPN * nmod
# clear * clear * PROPN * amod
# sit * sit * VERB * compound
# chair * chair * NOUN * nsubj
# let * let * VERB * ccomp
# prea * prea * PROPN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 823 * 823 * NUM * nummod
#                                                  *                                                  * SPACE * dep
# pray * pray * NOUN * nsubj
#
#  *
#  * SPACE * dep
# 824 * 824 * NUM * nummod
#     *     * SPACE * dep
# well * well * ADV * advmod
# consider * consider * VERB * ROOT
# case * case * NOUN * dobj
# two * two * NUM * nummod
# point * point * NOUN * appos
# young * young * ADJ * amod
# mccarthy * mccarthy * PROPN * compound
# na * na * NOUN * ccomp
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 825 * 825 * NUM * nsubj
#                                                 *                                                 * SPACE * dep
# cooee * cooee * ADJ * ROOT
#
#  *
#  * SPACE * dep
# 826 * 826 * NUM * dobj
#     *     * SPACE * dep
# well * well * INTJ * intj
# obviously * obviously * ADV * advmod
# could * could * AUX * aux
# mean * mean * VERB * ccomp
# son * son * PROPN * nsubj
# son * son * PROPN * appos
# far * far * ADV * advmod
# know * know * PROPN * compound
# bri * bri * PROPN * nsubj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 827 * 827 * NUM * nummod
#                                                   *                                                   * SPACE * dep
# rat * rat * NOUN * compound
#
#  *
#  * SPACE * dep
# 828 * 828 * NUM * compound
#     *     * SPACE * dep
# sherlock * sherlock * NOUN * compound
# holme * holme * NOUN * nsubj
# take * take * VERB * ccomp
# fold * fold * ADJ * amod
# paper * paper * NOUN * compound
# pocket * pocket * NOUN * compound
# flatten * flatten * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 829 * 829 * NUM * nummod
#                                             *                                             * SPACE * dep
# arat * arat * NOUN * nsubj
# read * read * NOUN * ROOT
#
#  *
#  * SPACE * dep
# 830 * 830 * NUM * dobj
#                                            *                                            * SPACE * dep
# raise * raise * VERB * conj
# hand * hand * NOUN * dobj
#
#  *
#  * SPACE * dep
# 831 * 831 * NUM * nummod
#                                              *                                              * SPACE * dep
# ballarat * ballarat * NOUN * npadvmod
#
#  *
#  * SPACE * dep
# 832 * 832 * NUM * compound
#     *     * SPACE * dep
# quite * quite * ADJ * amod
# word * word * NOUN * compound
# man * man * NOUN * nmod
# utter * utter * PROPN * compound
# son * son * PROPN * appos
# catch * catch * VERB * appos
# last * last * ADJ * amod
# two * two * NUM * nummod
# syllab * syllab * NOUN * appos
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 833 * 833 * NUM * nummod
#                                     *                                     * SPACE * dep
# wonderful * wonderful * ADJ * amod
# exclaim * exclaim * NOUN * nsubj
#
#  *
#  * SPACE * dep
# 834 * 834 * NUM * nummod
#     *     * SPACE * dep
# obvious * obvious * ADJ * amod
# see * see * VERB * conj
# narrow * narrow * ADJ * amod
# field * field * NOUN * nsubj
# considerably * considerably * ADV * advmod
# possessi * possessi * VERB * ccomp
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 835 * 835 * NUM * dep
#                                             *                                             * SPACE * dep
# certainly * certainly * ADV * advmod
#
#  *
#  * SPACE * dep
# 836 * 836 * NUM * compound
#     *     * SPACE * dep
# one * one * NUM * npadvmod
# home * home * NOUN * compound
# district * district * NOUN * compound
# pool * pool * NOUN * compound
# approach * approach * NOUN * compound
# farm * farm * PROPN * compound
# estate * estate * PROPN * compound
# st * st * PROPN * npadvmod
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 837 * 837 * NUM * nummod
#                                                 *                                                 * SPACE * dep
# quite * quite * DET * advmod
#
#  *
#  * SPACE * dep
# 838 * 838 * NUM * nsubj
#     *     * SPACE * dep
# come * come * VERB * conj
# expedition * expedition * NOUN * compound
# day * day * NOUN * compound
# examination * examination * NOUN * compound
# ground * ground * NOUN * compound
# gain * gain * NOUN * dobj
# tr * tr * VERB * advcl
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 839 * 839 * NUM * nummod
#                                                  *                                                  * SPACE * dep
# gain * gain * NOUN * compound
#
#  *
#  * SPACE * dep
# 840 * 840 * NUM * compound
#             *             * SPACE * dep
# know * know * NOUN * compound
# method * method * NOUN * dobj
# found * find * VERB * acl
# upon * upon * SCONJ * prep
# observation * observation * NOUN * compound
# trifle * trifle * NOUN * compound
#
#  *
#  * SPACE * dep
# 841 * 841 * NUM * nummod
#     *     * SPACE * dep
# height * height * NOUN * compound
# know * know * VERB * nsubj
# might * might * AUX * aux
# roughly * roughly * ADV * advmod
# judge * judge * VERB * ccomp
# length * length * NOUN * compound
# stride * stride * NOUN * dobj
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 842 * 842 * NUM * compound
#                                     *                                     * SPACE * dep
# yes * yes * INTJ * nummod
# peculiar * peculiar * ADJ * amod
# boot * boot * NOUN * nmod
#
#  *
#  * SPACE * dep
# 843 * 843 * NUM * nummod
#                                              *                                              * SPACE * dep
# lameness * lameness * NOUN * appos
#
#  *
#  * SPACE * dep
# 844 * 844 * NUM * nummod
#     *     * SPACE * dep
# impression * impression * NOUN * appos
# right * right * ADJ * amod
# foot * foot * NOUN * nsubj
# always * always * ADV * advmod
# less * less * ADV * advmod
# distinct * distinct * ADJ * amod
# lef * lef * NOUN * appos
# ... * ... * PUNCT * punct
#
#  *
#  * SPACE * dep
# 845 * 845 * NUM * nummod
#                                       *                                       * SPACE * dep
# left * leave * VERB * ROOT
# handedness * handedness * NOUN * dobj

# %%
#Done using NLTK:
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
import nltk
nltk.download('averaged_perceptron_tagger')

# get the first 1021 characters of big_txt_normalized
text = big_txt_normalized[:1021]

# tokenize the text
tokens = word_tokenize(text.to_string())

# get the POS tags and lemmatize the tokens
tagged_tokens = pos_tag(tokens)
lemmatizer = WordNetLemmatizer()
for token in tagged_tokens:
    print(token[0],"*", lemmatizer.lemmatize(token[0]), "*", token[1])
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\jeroc\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# 0 * 0 * CD
# project * project * NN
# gutenberg * gutenberg * NN
# ebook * ebook * NN
# adventure * adventure * NN
# sherlock * sherlock * NN
# holme * holme * VBD
# 1 * 1 * CD
# sir * sir * NN
# arthur * arthur * NN
# conan * conan * NN
# doyle * doyle * VBD
# 2 * 2 * CD
# series * series * NN
# sir * sir * NN
# arthur * arthur * IN
# conan * conan * JJ
# doyle * doyle * JJ
# 3 * 3 * CD
# copyright * copyright * JJ
# law * law * NN
# change * change * NN
# world * world * NN
# sure * sure * JJ
# check * check * VB
# 4 * 4 * CD
# copyright * copyright * JJ
# law * law * NN
# country * country * NN
# download * download * VBD
# redistribute * redistribute * JJ
# 5 * 5 * CD
# project * project * NN
# gutenberg * gutenberg * NN
# ebook * ebook * VBD
# 6 * 6 * CD
# header * header * NN
# first * first * JJ
# thing * thing * NN
# see * see * NN
# view * view * NN
# project * project * VBP
# 7 * 7 * CD
# gutenberg * gutenberg * NNS
# file * file * JJ
# please * please * NN
# remove * remove * VB
# change * change * NN
# edit * edit * NN
# 8 * 8 * CD
# header * header * NN
# without * without * IN
# write * write * JJ
# permission * permission * NN
# 9 * 9 * CD
# please * please * NN
# read * read * JJ
# legal * legal * JJ
# small * small * JJ
# print * print * NN
# information * information * NN
# 10 * 10 * CD
# ebook * ebook * NN
# project * project * NN
# gutenberg * gutenberg * JJ
# bottom * bottom * NN
# file * file * NN
# include * include * VBP
# 11 * 11 * CD
# important * important * JJ
# information * information * NN
# specific * specific * JJ
# right * right * JJ
# restriction * restriction * NN
# 12 * 12 * CD
# file * file * NN
# may * may * MD
# use * use * VB
# also * also * RB
# find * find * VBP
# make * make * JJ
# 13 * 13 * CD
# donation * donation * NN
# project * project * NN
# gutenberg * gutenberg * NN
# get * get * VB
# involve * involve * JJ
# 14 * 14 * CD
# welcome * welcome * JJ
# world * world * NN
# free * free * JJ
# plain * plain * NN
# vanilla * vanilla * NN
# electronic * electronic * JJ
# text * text * NN
# 15 * 15 * CD
# ebook * ebook * NN
# readable * readable * JJ
# human * human * JJ
# computer * computer * NN
# since * since * IN
# 16 * 16 * CD
# ebook * ebook * NN
# prepare * prepare * NN
# thousand * thousand * CD
# volunteer * volunteer * NN
# 17 * 17 * CD
# title * title * NN
# adventure * adventure * NN
# sherlock * sherlock * NN
# holme * holme * VBD
# 18 * 18 * CD
# author * author * NN
# sir * sir * NN
# arthur * arthur * NN
# conan * conan * NN
# doyle * doyle * VBZ
# 19 * 19 * CD
# release * release * NN
# date * date * NN
# march * march * NN
# [ * [ * NNP
# ebook * ebook * NN
# ] * ] * VBD
# 20 * 20 * CD
# [ * [ * NNS
# recently * recently * RB
# update * update * JJ
# november * november * NN
# ] * ] * VBD
# 21 * 21 * CD
# edition * edition * NN
# 22 * 22 * CD
# language * language * NN
# english * english * JJ
# 23 * 23 * CD
# character * character * NN
# set * set * VBN
# encoding * encoding * VBG
# ascii * ascii * JJ
# 24 * 24 * CD
# start * start * NN
# project * project * NN
# gutenberg * gutenberg * NN
# ebook * ebook * NN
# adventure * adventure * NN
# sherlo * sherlo * NN
# ... * ... * :
# 25 * 25 * CD
# additional * additional * JJ
# editing * editing * VBG
# jose * jose * JJ
# menendez * menendez * NNS
# 26 * 26 * CD
# adventure * adventure * NN
# 27 * 27 * CD
# sherlock * sherlock * NN
# holme * holme * VBD
# 28 * 28 * CD
# 29 * 29 * CD
# sir * sir * NN
# arthur * arthur * NN
# conan * conan * NN
# doyle * doyle * VBZ
# 30 * 30 * CD
# content * content * NN
# 31 * 31 * CD
# scandal * scandal * NN
# bohemia * bohemia * NN
# 32 * 32 * CD
# ii * ii * NN
# red * red * JJ
# head * head * NN
# league * league * NN
# 33 * 33 * CD
# iii * iii * NN
# case * case * NN
# identity * identity * NN
# 34 * 34 * CD
# iv * iv * NN
# boscombe * boscombe * NN
# valley * valley * NN
# mystery * mystery * NN
# 35 * 35 * CD
# v * v * NN
# five * five * CD
# orange * orange * NN
# pip * pip * NN
# 36 * 36 * CD
# vi * vi * NN
# man * man * NN
# twisted * twisted * VBD
# lip * lip * JJ
# 37 * 37 * CD
# vii * vii * JJ
# adventure * adventure * NN
# blue * blue * JJ
# carbuncle * carbuncle * NN
# 38 * 38 * CD
# viii * viii * NN
# adventure * adventure * NN
# speckled * speckled * VBD
# band * band * RB
# 39 * 39 * CD
# ix * ix * JJ
# adventure * adventure * NN
# engineer * engineer * NN
# thumb * thumb * VBD
# 40 * 40 * CD
# x * x * JJ
# adventure * adventure * NN
# noble * noble * JJ
# bachelor * bachelor * NN
# 41 * 41 * CD
# xi * xi * JJ
# adventure * adventure * NN
# beryl * beryl * NN
# coronet * coronet * NN
# 42 * 42 * CD
# xii * xii * JJ
# adventure * adventure * NN
# copper * copper * NN
# beech * beech * NN
# 43 * 43 * CD
# adventure * adventure * NN
# scandal * scandal * NN
# bohemia * bohemia * VBD
# 44 * 44 * CD
# 45 * 45 * CD
# sherlock * sherlock * NN
# holme * holme * NN
# always * always * RB
# woman * woman * NN
# seldom * seldom * JJ
# hear * hear * JJ
# mentio * mentio * NN
# ... * ... * :
# 46 * 46 * CD
# see * see * NN
# little * little * JJ
# holme * holme * JJ
# lately * lately * RB
# marriage * marriage * NN
# drift * drift * NN
# away * away * RB
# co * co * VBD
# ... * ... * :
# 47 * 47 * CD
# one * one * CD
# night * night * NN
# twentieth * twentieth * VBZ
# march * march * JJ
# return * return * NN
# journey * journey * NN
# patie * patie * NN
# ... * ... * :
# 48 * 48 * CD
# manner * manner * NN
# effusive * effusive * JJ
# seldom * seldom * NN
# glad * glad * JJ
# think * think * VBP
# see * see * VBP
# hardly * hardly * RB
# w * w * VBP
# ... * ... * :
# 49 * 49 * CD
# wedlock * wedlock * NN
# suit * suit * NN
# remark * remark * NN
# think * think * VBP
# watson * watson * NN
# put * put * VBD
# seven * seven * CD
# hal * hal * NNS
# ... * ... * :
# 50 * 50 * CD
# seven * seven * CD
# answer * answer * JJR
# 51 * 51 * CD
# indeed * indeed * RB
# think * think * VBP
# little * little * JJ
# trifle * trifle * JJ
# fancy * fancy * JJ
# watson * watson * NN
# practi * practi * NN
# ... * ... * :
# 52 * 52 * CD
# know * know * VBP
# 53 * 53 * CD
# see * see * VBP
# deduce * deduce * NN
# know * know * VBP
# get * get * VB
# wet * wet * JJ
# lately * lately * RB
# clumsy * clumsy * JJ
# careless * careless * NN
# ... * ... * :
# 54 * 54 * CD
# dear * dear * JJ
# holme * holme * NNS
# say * say * VBP
# much * much * RB
# would * would * MD
# certainly * certainly * RB
# burn * burn * VB
# live * live * JJ
# ... * ... * :
# 55 * 55 * CD
# chuckle * chuckle * NNS
# rub * rub * VBP
# long * long * RB
# nervous * nervous * JJ
# hand * hand * NN
# together * together * RB
# 56 * 56 * CD
# simplicity * simplicity * NN
# say * say * VBP
# eye * eye * NN
# tell * tell * NN
# inside * inside * IN
# left * left * VBD
# shoe * shoe * JJ
# firel * firel * NN
# ... * ... * :
# 57 * 57 * CD
# could * could * MD
# help * help * VB
# laugh * laugh * IN
# ease * ease * NN
# explain * explain * NN
# process * process * NN
# deductio * deductio * NN
# ... * ... * :
# 58 * 58 * CD
# quite * quite * RB
# answer * answer * JJR
# light * light * JJ
# cigarette * cigarette * NN
# throw * throw * NN
# armchair * armchair * NN
# se * se * VBD
# ... * ... * :
# 59 * 59 * CD
# frequently * frequently * RB
# 60 * 60 * CD
# often * often * RB
# 61 * 61 * CD
# well * well * RB
# hundred * hundred * JJ
# time * time * NN
# 62 * 62 * CD
# many * many * JJ
# 63 * 63 * CD
# many * many * JJ
# know * know * VBP
# 64 * 64 * CD
# quite * quite * RB
# observe * observe * JJ
# yet * yet * RB
# see * see * VBP
# point * point * NN
# know * know * VBP
# seventeen * seventeen * JJ
# ste * ste * NN
# ... * ... * :
# 65 * 65 * CD
# note * note * NN
# undated * undated * VBD
# without * without * IN
# either * either * DT
# signature * signature * NN
# address * address * NN
# 66 * 66 * CD
# call * call * NN
# upon * upon * IN
# night * night * NN
# quarter * quarter * NN
# eight * eight * CD
# oclock * oclock * NNS
# say * say * VBP
# gentl * gentl * NNS
# ... * ... * :
# 67 * 67 * CD
# indeed * indeed * RB
# mystery * mystery * JJ
# remark * remark * NN
# imagine * imagine * NN
# mean * mean * VBP
# 68 * 68 * CD
# datum * datum * NN
# yet * yet * RB
# capital * capital * JJ
# mistake * mistake * NN
# theorise * theorise * NN
# one * one * CD
# datum * datum * NN
# i * i * NN
# ... * ... * :
# 69 * 69 * CD
# carefully * carefully * RB
# examine * examine * JJ
# writing * writing * VBG
# paper * paper * NN
# upon * upon * IN
# write * write * JJ
# 70 * 70 * CD
# man * man * NN
# write * write * NN
# presumably * presumably * RB
# well * well * RB
# remark * remark * VB
# endeavour * endeavour * NN
# imi * imi * NN
# ... * ... * :
# 71 * 71 * CD
# peculiar * peculiar * JJ
# word * word * NN
# say * say * VBP
# holme * holme * JJ
# english * english * JJ
# paper * paper * NN
# hold * hold * NN
# light * light * JJ
# 72 * 72 * CD
# see * see * VBP
# large * large * JJ
# e * e * VB
# small * small * JJ
# g * g * NN
# p * p * NN
# large * large * JJ
# g * g * NN
# small * small * JJ
# weave * weave * VBP
# text * text * NN
# ... * ... * :
# 73 * 73 * CD
# make * make * VBP
# ask * ask * JJ
# holme * holme * NN
# 74 * 74 * CD
# name * name * NN
# maker * maker * NN
# doubt * doubt * NN
# monogram * monogram * NN
# rather * rather * RB
# 75 * 75 * CD
# g * g * NNS
# small * small * JJ
# stand * stand * VBP
# gesellschaft * gesellschaft * JJ
# german * german * JJ
# company * company * NN
# cust * cust * NN
# ... * ... * :
# 76 * 76 * CD
# paper * paper * NN
# make * make * NN
# bohemia * bohemia * NNS
# say * say * VBP
# 77 * 77 * CD
# precisely * precisely * RB
# man * man * NN
# write * write * JJ
# note * note * JJ
# german * german * JJ
# note * note * NN
# peculiar * peculiar * NN
# ... * ... * :
# 78 * 78 * CD
# speak * speak * NN
# sharp * sharp * JJ
# sound * sound * JJ
# horse * horse * NN
# hoof * hoof * NN
# grate * grate * NN
# wheel * wheel * NN
# curb * curb * NN
# ... * ... * :
# 79 * 79 * CD
# pair * pair * NN
# sound * sound * JJ
# say * say * VBP
# yes * yes * UH
# continue * continue * VBP
# glance * glance * NN
# window * window * NN
# nice * nice * NN
# ... * ... * :
# 80 * 80 * CD
# think * think * NN
# well * well * RB
# go * go * VB
# holme * holme * RB
# 81 * 81 * CD
# bit * bit * NN
# doctor * doctor * JJ
# stay * stay * NN
# lose * lose * VB
# without * without * IN
# boswell * boswell * NN
# promise * promise * NN
# i * i * NN
# ... * ... * :
# 82 * 82 * CD
# client * client * NN
# 83 * 83 * CD
# never * never * RB
# mind * mind * NN
# may * may * MD
# want * want * VB
# help * help * NN
# may * may * MD
# come * come * VB
# sit * sit * NN
# armchair * armchair * NN
# ... * ... * :
# 84 * 84 * CD
# slow * slow * JJ
# heavy * heavy * JJ
# step * step * NN
# hear * hear * VBP
# upon * upon * IN
# stair * stair * JJ
# passage * passage * NN
# pause * pause * NN
# ... * ... * :
# 85 * 85 * CD
# come * come * NNS
# say * say * VBP
# holme * holme * JJ
# 86 * 86 * CD
# man * man * NN
# enter * enter * NN
# could * could * MD
# hardly * hardly * RB
# less * le * RBR
# six * six * CD
# foot * foot * NN
# six * six * CD
# inch * inch * NN
# ... * ... * :
# 87 * 87 * CD
# note * note * NN
# ask * ask * NN
# deep * deep * JJ
# harsh * harsh * JJ
# voice * voice * NN
# strongly * strongly * RB
# marked * marked * VBD
# germ * germ * NNS
# ... * ... * :
# 88 * 88 * CD
# pray * pray * NNS
# take * take * JJ
# seat * seat * NN
# say * say * VBP
# holme * holme * NN
# friend * friend * NN
# colleague * colleague * NN
# dr * dr * NN
# w * w * NN
# ... * ... * :
# 89 * 89 * CD
# may * may * MD
# address * address * VB
# count * count * NN
# von * von * JJ
# kramm * kramm * NN
# bohemian * bohemian * JJ
# nobleman * nobleman * NN
# ... * ... * :
# 90 * 90 * CD
# rise * rise * NN
# go * go * VBP
# holme * holme * JJ
# catch * catch * NN
# wrist * wrist * NN
# push * push * NN
# back * back * RB
# chair * chair * NN
# none * none * NN
# ... * ... * :
# 91 * 91 * CD
# count * count * NN
# shrug * shrug * NN
# broad * broad * JJ
# shoulder * shoulder * NN
# must * must * MD
# begin * begin * VB
# say * say * VB
# bind * bind * NN
# ... * ... * :
# 92 * 92 * CD
# promise * promise * NNS
# say * say * VBP
# holme * holme * JJ
# 93 * 93 * CD
# 94 * 94 * CD
# excuse * excuse * NN
# mask * mask * NN
# continue * continue * VBP
# strange * strange * JJ
# visitor * visitor * NN
# august * august * NN
# pe * pe * NN
# ... * ... * :
# 95 * 95 * CD
# aware * aware * JJ
# say * say * VBP
# holmes * holmes * NNS
# dryly * dryly * VBP
# 96 * 96 * CD
# circumstance * circumstance * NN
# great * great * JJ
# delicacy * delicacy * NN
# every * every * DT
# precaution * precaution * NN
# t * t * NN
# ... * ... * :
# 97 * 97 * CD
# also * also * RB
# aware * aware * JJ
# murmur * murmur * NN
# holme * holme * NN
# settle * settle * VB
# armchair * armchair * NN
# close * close * JJ
# eye * eye * NN
# 98 * 98 * CD
# visitor * visitor * NN
# glance * glance * NN
# apparent * apparent * JJ
# surprise * surprise * NN
# languid * languid * NN
# loung * loung * NN
# ... * ... * :
# 99 * 99 * CD
# majesty * majesty * NN
# would * would * MD
# condescend * condescend * VB
# state * state * NN
# case * case * NN
# remark * remark * NN
# wel * wel * NN
# ... * ... * :
# 100 * 100 * CD
# man * man * NN
# spring * spring * NN
# chair * chair * JJ
# pace * pace * NN
# room * room * NN
# uncontrollable * uncontrollable * JJ
# agit * agit * NN
# ... * ... * :
# 101 * 101 * CD
# indeed * indeed * RB
# murmur * murmur * JJ
# holme * holme * NN
# majesty * majesty * NN
# speak * speak * NN
# aware * aware * JJ
# addres * addres * NNS
# ... * ... * :
# 102 * 102 * CD
# understand * understand * NNS
# say * say * VBP
# strange * strange * JJ
# visitor * visitor * NN
# sit * sit * NN
# pass * pas * NN
# hand * hand * NN
# h * h * NN
# ... * ... * :
# 103 * 103 * CD
# pray * pray * NN
# consult * consult * NNS
# say * say * VBP
# holme * holme * JJ
# shut * shut * NN
# eye * eye * NN
# 104 * 104 * CD
# fact * fact * NN
# briefly * briefly * NN
# five * five * CD
# year * year * NN
# ago * ago * RB
# lengthy * lengthy * JJ
# visit * visit * NN
# warsa * warsa * NN
# ... * ... * :
# 105 * 105 * CD
# kindly * kindly * RB
# look * look * VBP
# index * index * NN
# doctor * doctor * NN
# murmur * murmur * NN
# holme * holme * NN
# without * without * IN
# ... * ... * :
# 106 * 106 * CD
# let * let * NN
# see * see * VB
# say * say * VB
# holmes * holmes * NNS
# hum * hum * VBP
# bear * bear * JJ
# new * new * JJ
# jersey * jersey * NN
# year * year * NN
# co * co * NN
# ... * ... * :
# 107 * 107 * CD
# precisely * precisely * RB
# 108 * 108 * CD
# secret * secret * JJ
# marriage * marriage * NN
# 109 * 109 * CD
# none * none * NN
# 110 * 110 * CD
# legal * legal * JJ
# paper * paper * NN
# certificate * certificate * NN
# 111 * 111 * CD
# none * none * NN
# 112 * 112 * CD
# fail * fail * NN
# follow * follow * NN
# majesty * majesty * NN
# young * young * JJ
# person * person * NN
# produce * produce * VBP
# lette * lette * NN
# ... * ... * :
# 113 * 113 * CD
# writing * writing * VBG
# 114 * 114 * CD
# pooh * pooh * JJ
# pooh * pooh * NN
# forgery * forgery * NN
# 115 * 115 * CD
# private * private * JJ
# note * note * NN
# paper * paper * NN
# 116 * 116 * CD
# steal * steal * JJ
# 117 * 117 * CD
# seal * seal * JJ
# 118 * 118 * CD
# imitate * imitate * JJ
# 119 * 119 * CD
# photograph * photograph * NN
# 120 * 120 * CD
# buy * buy * NN
# 121 * 121 * CD
# photograph * photograph * NN
# 122 * 122 * CD
# oh * oh * JJ
# dear * dear * JJ
# bad * bad * JJ
# majesty * majesty * NNS
# indeed * indeed * RB
# commit * commit * VBP
# indiscretion * indiscretion * NN
# 123 * 123 * CD
# mad * mad * JJ
# insane * insane * NN
# 124 * 124 * CD
# compromise * compromise * NN
# seriously * seriously * RB
# 125 * 125 * CD
# crown * crown * JJ
# prince * prince * NN
# young * young * JJ
# thirty * thirty * NN
# 126 * 126 * CD
# must * must * MD
# recover * recover * VB
# 127 * 127 * CD
# try * try * NN
# fail * fail * VBD
# 128 * 128 * CD
# majesty * majesty * JJ
# must * must * MD
# pay * pay * VB
# must * must * MD
# buy * buy * VB
# 129 * 129 * CD
# sell * sell * NN
# 130 * 130 * CD
# steal * steal * NN
# 131 * 131 * CD
# five * five * CD
# attempt * attempt * NNS
# make * make * VBP
# twice * twice * RB
# burglar * burglar * JJ
# pay * pay * NN
# ransack * ransack * NN
# ho * ho * NN
# ... * ... * :
# 132 * 132 * CD
# sign * sign * NN
# 133 * 133 * CD
# absolutely * absolutely * RB
# none * none * NN
# 134 * 134 * CD
# holme * holme * NN
# laugh * laugh * IN
# quite * quite * RB
# pretty * pretty * JJ
# little * little * JJ
# problem * problem * NN
# say * say * VBP
# 135 * 135 * CD
# serious * serious * JJ
# one * one * CD
# return * return * NN
# king * king * VBG
# reproachfully * reproachfully * RB
# 136 * 136 * CD
# indeed * indeed * RB
# propose * propose * JJ
# photograph * photograph * NN
# 137 * 137 * CD
# ruin * ruin * NN
# 138 * 138 * CD
# 139 * 139 * CD
# marry * marry * NN
# 140 * 140 * CD
# hear * hear * JJ
# 141 * 141 * CD
# clotilde * clotilde * JJ
# lothman * lothman * NN
# von * von * NN
# saxe * saxe * NN
# meningen * meningen * NN
# second * second * JJ
# daug * daug * NN
# ... * ... * :
# 142 * 142 * CD
# irene * irene * JJ
# adler * adler * NN
# 143 * 143 * CD
# threaten * threaten * JJ
# send * send * JJ
# photograph * photograph * NN
# know * know * VBP
# know * know * VBP
# soul * soul * JJ
# steel * steel * NN
# ... * ... * :
# 144 * 144 * CD
# sure * sure * JJ
# send * send * NN
# yet * yet * RB
# 145 * 145 * CD
# sure * sure * JJ
# 146 * 146 * CD
# 147 * 147 * CD
# say * say * NN
# would * would * MD
# send * send * VB
# day * day * NN
# betrothal * betrothal * IN
# publicly * publicly * RB
# proclaim * proclaim * NN
# ... * ... * :
# 148 * 148 * CD
# oh * oh * JJ
# three * three * CD
# day * day * NN
# yet * yet * RB
# say * say * VBP
# holme * holme * JJ
# yawn * yawn * NN
# fortunate * fortunate * NN
# one * one * CD
# ... * ... * :
# 149 * 149 * CD
# certainly * certainly * RB
# find * find * VBP
# langham * langham * JJ
# name * name * NN
# count * count * NN
# von * von * NNP
# kramm * kramm * VBD
# 150 * 150 * CD
# shall * shall * MD
# drop * drop * VB
# line * line * NN
# let * let * NN
# know * know * VB
# progress * progress * VB
# 151 * 151 * CD
# pray * pray * NN
# shall * shall * MD
# anxiety * anxiety * VB
# 152 * 152 * CD
# money * money * NN
# 153 * 153 * CD
# carte * carte * NN
# blanche * blanche * NN
# 154 * 154 * CD
# absolutely * absolutely * RB
# 155 * 155 * CD
# tell * tell * NN
# would * would * MD
# give * give * VB
# one * one * CD
# province * province * NN
# kingdom * kingdom * NN
# photograph * photograph * NN
# 156 * 156 * CD
# present * present * JJ
# expense * expense * NN
# 157 * 157 * CD
# king * king * VBG
# take * take * VB
# heavy * heavy * JJ
# chamois * chamois * NN
# leather * leather * RBR
# bag * bag * NN
# cloak * cloak * NN
# lay * lay * VBD
# ... * ... * :
# 158 * 158 * CD
# three * three * CD
# hundred * hundred * VBN
# pound * pound * NN
# gold * gold * NN
# seven * seven * CD
# hundred * hundred * VBD
# note * note * NNS
# say * say * VBP
# 159 * 159 * CD
# holme * holme * NN
# scribble * scribble * JJ
# receipt * receipt * NN
# upon * upon * IN
# sheet * sheet * NN
# note * note * NN
# book * book * NN
# hand * hand * NN
# 160 * 160 * CD
# mademoiselle * mademoiselle * NN
# address * address * NN
# ask * ask * VBD
# 161 * 161 * CD
# briony * briony * NN
# lodge * lodge * NN
# serpentine * serpentine * NN
# avenue * avenue * NN
# st * st * NN
# john * john * NN
# wood * wood * NN
# 162 * 162 * CD
# holme * holme * NNS
# take * take * VBP
# note * note * VBP
# one * one * CD
# question * question * NN
# say * say * VBP
# photograph * photograph * NN
# ca * ca * MD
# ... * ... * :
# 163 * 163 * CD
# 164 * 164 * CD
# good * good * JJ
# night * night * NN
# majesty * majesty * NN
# trust * trust * NN
# shall * shall * MD
# soon * soon * RB
# good * good * JJ
# news * news * NN
# ... * ... * :
# 165 * 165 * CD
# ii * ii * NN
# 166 * 166 * CD
# three * three * CD
# oclock * oclock * NN
# precisely * precisely * RB
# baker * baker * JJ
# street * street * NN
# holme * holme * NN
# yet * yet * RB
# ... * ... * :
# 167 * 167 * CD
# close * close * JJ
# upon * upon * IN
# four * four * CD
# door * door * NN
# open * open * JJ
# drunken * drunken * VBN
# look * look * NN
# groom * groom * NN
# i * i * NN
# ... * ... * :
# 168 * 168 * CD
# well * well * RB
# really * really * RB
# cry * cry * JJ
# choke * choke * NN
# laugh * laugh * IN
# oblige * oblige * JJ
# lie * lie * NN
# back * back * RB
# li * li * NN
# ... * ... * :
# 169 * 169 * CD
# 170 * 170 * CD
# quite * quite * RB
# funny * funny * JJ
# sure * sure * NN
# could * could * MD
# never * never * RB
# guess * guess * VB
# employ * employ * NN
# morn * morn * NN
# ... * ... * :
# 171 * 171 * CD
# imagine * imagine * NN
# suppose * suppose * JJ
# watch * watch * NN
# habit * habit * NN
# perhaps * perhaps * RB
# house * house * NN
# miss * miss * NN
# ... * ... * :
# 172 * 172 * CD
# quite * quite * RB
# sequel * sequel * JJ
# rather * rather * RB
# unusual * unusual * JJ
# tell * tell * VB
# however * however * RB
# leave * leave * VBP
# ... * ... * :
# 173 * 173 * CD
# lounge * lounge * JJ
# street * street * NN
# find * find * NNS
# expect * expect * VBP
# mew * mew * JJ
# lane * lane * NN
# run * run * VB
# one * one * CD
# wal * wal * NN
# ... * ... * :
# 174 * 174 * CD
# irene * irene * JJ
# adler * adler * NN
# ask * ask * NN
# 175 * 175 * CD
# oh * oh * JJ
# turn * turn * NN
# man * man * NN
# head * head * VBP
# part * part * NN
# dainty * dainty * JJ
# thing * thing * NN
# bonnet * bonnet * NN
# plan * plan * NN
# ... * ... * :
# 176 * 176 * CD
# godfrey * godfrey * JJ
# norton * norton * RB
# evidently * evidently * RB
# important * important * JJ
# factor * factor * NN
# matt * matt * NN
# ... * ... * :
# 177 * 177 * CD
# follow * follow * VBP
# closely * closely * RB
# answer * answer * VBP
# 178 * 178 * CD
# still * still * RB
# balance * balance * VB
# matter * matter * NN
# mind * mind * NN
# hansom * hansom * NN
# cab * cab * NN
# drive * drive * NN
# bri * bri * NN
# ... * ... * :
# 179 * 179 * CD
# house * house * NN
# half * half * NN
# hour * hour * NN
# could * could * MD
# catch * catch * VB
# glimpse * glimpse * NN
# window * window * NN
# sit * sit * NN
# ... * ... * :
# 180 * 180 * CD
# away * away * RB
# go * go * VB
# wonder * wonder * RBR
# whether * whether * IN
# well * well * RB
# follow * follow * VB
# lane * lane * NN
# come * come * NN
# n * n * NN
# ... * ... * :
# 181 * 181 * CD
# church * church * NN
# st * st * NN
# monica * monica * NN
# john * john * NN
# cry * cry * NN
# half * half * NN
# sovereign * sovereign * JJ
# reach * reach * NN
# ... * ... * :
# 182 * 182 * CD
# quite * quite * RB
# good * good * JJ
# lose * lose * JJ
# watson * watson * NN
# balance * balance * NN
# whether * whether * IN
# run * run * NN
# whe * whe * NN
# ... * ... * :
# 183 * 183 * CD
# cabby * cabby * NN
# drive * drive * NN
# fast * fast * NN
# think * think * VBP
# ever * ever * RB
# drive * drive * VBP
# fast * fast * JJ
# cab * cab * NN
# lan * lan * NN
# ... * ... * :
# 184 * 184 * CD
# thank * thank * NN
# god * god * NN
# cry * cry * VBZ
# come * come * VBN
# come * come * JJ
# 185 * 185 * CD
# ask * ask * NN
# 186 * 186 * CD
# come * come * NN
# man * man * NN
# come * come * VBP
# three * three * CD
# minute * minute * JJ
# legal * legal * JJ
# 187 * 187 * CD
# half * half * NN
# drag * drag * JJ
# altar * altar * NN
# know * know * VBP
# find * find * VBP
# mumbling * mumbling * JJ
# response * response * NN
# wh * wh * NN
# ... * ... * :
# 188 * 188 * CD
# unexpected * unexpected * JJ
# turn * turn * NN
# affair * affair * NNS
# say * say * VBP
# 189 * 189 * CD
# well * well * RB
# find * find * VB
# plan * plan * NN
# seriously * seriously * RB
# menace * menace * JJ
# look * look * VBP
# pair * pair * JJ
# migh * migh * NNS
# ... * ... * :
# 190 * 190 * CD
# 191 * 191 * CD
# cold * cold * JJ
# beef * beef * NN
# glass * glass * NN
# beer * beer * NN
# answer * answer * IN
# ring * ring * VBG
# bell * bell * NN
# busy * busy * JJ
# thi * thi * NN
# ... * ... * :
# 192 * 192 * CD
# shall * shall * MD
# delight * delight * VB
# 193 * 193 * CD
# mind * mind * NN
# break * break * NN
# law * law * NN
# 194 * 194 * CD
# least * least * JJS
# 195 * 195 * CD
# run * run * JJ
# chance * chance * NN
# arrest * arrest * NN
# 196 * 196 * CD
# good * good * JJ
# cause * cause * NN
# 197 * 197 * CD
# oh * oh * NN
# cause * cause * NN
# excellent * excellent * JJ
# 198 * 198 * CD
# man * man * NN
# 199 * 199 * CD
# sure * sure * JJ
# might * might * MD
# rely * rely * RB
# 200 * 200 * CD
# wish * wish * JJ
# 201 * 201 * CD
# mrs * mr * NN
# turner * turner * NN
# bring * bring * VBP
# tray * tray * JJ
# make * make * VBP
# clear * clear * JJ
# say * say * VBP
# turn * turn * NN
# hung * hung * NN
# ... * ... * :
# 202 * 202 * CD
# 203 * 203 * CD
# must * must * MD
# leave * leave * VB
# already * already * RB
# arrange * arrange * JJ
# occur * occur * VBP
# one * one * CD
# point * point * NN
# mus * mu * NN
# ... * ... * :
# 204 * 204 * CD
# neutral * neutral * JJ
# 205 * 205 * CD
# nothing * nothing * NN
# whatever * whatever * WDT
# probably * probably * RB
# small * small * JJ
# unpleasantness * unpleasantness * NN
# ... * ... * :
# 206 * 206 * CD
# yes * yes * NNS
# 207 * 207 * CD
# watch * watch * NN
# visible * visible * JJ
# 208 * 208 * CD
# yes * yes * RB
# 209 * 209 * CD
# raise * raise * NN
# hand * hand * NN
# throw * throw * VBP
# room * room * NN
# give * give * VB
# throw * throw * NN
# time * time * NN
# raise * raise * VB
# cr * cr * NN
# ... * ... * :
# 210 * 210 * CD
# entirely * entirely * RB
# 211 * 211 * CD
# nothing * nothing * NN
# formidable * formidable * JJ
# say * say * VBP
# take * take * VB
# long * long * JJ
# cigar * cigar * NN
# shape * shape * NN
# r * r * NN
# ... * ... * :
# 212 * 212 * CD
# remain * remain * VBP
# neutral * neutral * JJ
# get * get * NN
# near * near * IN
# window * window * JJ
# watch * watch * NN
# signal * signal * NN
# th * th * NN
# ... * ... * :
# 213 * 213 * CD
# precisely * precisely * RB
# 214 * 214 * CD
# may * may * MD
# entirely * entirely * RB
# rely * rely * VB
# 215 * 215 * CD
# excellent * excellent * JJ
# think * think * NN
# perhaps * perhaps * RB
# almost * almost * RB
# time * time * NN
# prepare * prepare * JJ
# ne * ne * NNS
# ... * ... * :
# 216 * 216 * CD
# disappear * disappear * JJ
# bedroom * bedroom * NN
# return * return * NN
# minute * minute * NN
# character * character * NN
# amia * amia * NN
# ... * ... * :
# 217 * 217 * CD
# quarter * quarter * NN
# past * past * IN
# six * six * CD
# leave * leave * VBP
# baker * baker * VBN
# street * street * NN
# still * still * RB
# want * want * VBP
# ... * ... * :
# 218 * 218 * CD
# see * see * VBP
# remark * remark * NN
# holme * holme * JJ
# pace * pace * NN
# fro * fro * NN
# front * front * JJ
# house * house * NN
# marriage * marriage * NN
# ... * ... * :
# 219 * 219 * CD
# indeed * indeed * RB
# 220 * 220 * CD
# unlikely * unlikely * JJ
# carry * carry * JJ
# cabinet * cabinet * NN
# size * size * NN
# large * large * JJ
# easy * easy * JJ
# conceal * conceal * NN
# ... * ... * :
# 221 * 221 * CD
# 222 * 222 * CD
# banker * banker * NN
# lawyer * lawyer * NN
# double * double * JJ
# possibility * possibility * NN
# inclined * inclined * VBN
# thin * thin * JJ
# ... * ... * :
# 223 * 223 * CD
# twice * twice * RB
# burgle * burgle * RB
# 224 * 224 * CD
# pshaw * pshaw * NNS
# know * know * VBP
# look * look * VBP
# 225 * 225 * CD
# look * look * NN
# 226 * 226 * CD
# look * look * NN
# 227 * 227 * CD
# 228 * 228 * CD
# get * get * NN
# show * show * NN
# 229 * 229 * CD
# refuse * refuse * NN
# 230 * 230 * CD
# able * able * JJ
# hear * hear * JJ
# rumble * rumble * JJ
# wheel * wheel * NN
# carriage * carriage * NN
# carry * carry * NN
# order * order * NN
# le * le * NN
# ... * ... * :
# 231 * 231 * CD
# speak * speak * JJ
# gleam * gleam * NN
# sidelight * sidelight * VBD
# carriage * carriage * NN
# come * come * VBN
# round * round * NN
# curv * curv * NN
# ... * ... * :
# 232 * 232 * CD
# poor * poor * JJ
# gentleman * gentleman * NN
# much * much * JJ
# hurt * hurt * NN
# ask * ask * VBD
# 233 * 233 * CD
# dead * dead * JJ
# cry * cry * NN
# several * several * JJ
# voice * voice * NN
# 234 * 234 * CD
# life * life * NN
# shout * shout * NN
# another * another * DT
# go * go * VBP
# get * get * VB
# hospital * hospital * JJ
# 235 * 235 * CD
# brave * brave * JJ
# fellow * fellow * NNS
# say * say * VBP
# woman * woman * NN
# would * would * MD
# lady * lady * VB
# purse * purse * JJ
# watch * watch * NN
# ... * ... * :
# 236 * 236 * CD
# lie * lie * JJ
# street * street * NN
# may * may * MD
# bring * bring * VB
# marm * marm * NN
# 237 * 237 * CD
# surely * surely * RB
# bring * bring * JJ
# sitting * sitting * VBG
# room * room * NN
# comfortable * comfortable * JJ
# sofa * sofa * JJ
# way * way * NN
# ... * ... * :
# 238 * 238 * CD
# slowly * slowly * RB
# solemnly * solemnly * RB
# bear * bear * JJ
# briony * briony * NN
# lodge * lodge * NN
# lay * lay * VBD
# principa * principa * NN
# ... * ... * :
# 239 * 239 * CD
# holme * holme * NN
# sit * sit * NN
# upon * upon * IN
# couch * couch * JJ
# see * see * VBP
# motion * motion * NN
# like * like * IN
# man * man * NN
# need * need * VBP
# ... * ... * :
# 240 * 240 * CD
# nicely * nicely * RB
# doctor * doctor * JJ
# remark * remark * NN
# nothing * nothing * NN
# could * could * MD
# well * well * RB
# right * right * RB
# 241 * 241 * CD
# photograph * photograph * JJ
# 242 * 242 * CD
# know * know * VBP
# 243 * 243 * CD
# find * find * VBP
# 244 * 244 * CD
# show * show * NN
# tell * tell * NN
# would * would * MD
# 245 * 245 * CD
# still * still * RB
# dark * dark * JJ
# 246 * 246 * CD
# wish * wish * JJ
# make * make * NN
# mystery * mystery * NN
# say * say * VBP
# laugh * laugh * IN
# matter * matter * NN
# perfectly * perfectly * RB
# s * s * VBD
# ... * ... * :
# 247 * 247 * CD
# guess * guess * NN
# much * much * RB
# 248 * 248 * CD
# row * row * NN
# break * break * NN
# little * little * JJ
# moist * moist * JJ
# red * red * JJ
# paint * paint * NN
# palm * palm * NN
# hand * hand * NN
# rus * ru * NN
# ... * ... * :
# 249 * 249 * CD
# also * also * RB
# could * could * MD
# fathom * fathom * VB
# 250 * 250 * CD
# carry * carry * NN
# bind * bind * NN
# else * else * RB
# could * could * MD
# sitting * sitting * VBG
# room * room * NN
# room * room * NN
# suspec * suspec * NN
# ... * ... * :
# 251 * 251 * CD
# help * help * NN
# 252 * 252 * CD
# important * important * JJ
# woman * woman * NN
# think * think * VBP
# house * house * NN
# fire * fire * NN
# instinct * instinct * JJ
# rush * rush * NN
# ... * ... * :
# 253 * 253 * CD
# ask * ask * NN
# 254 * 254 * CD
# quest * quest * JJS
# practically * practically * RB
# finish * finish * JJ
# shall * shall * MD
# call * call * VB
# king * king * NN
# morro * morro * NN
# ... * ... * :
# 255 * 255 * CD
# call * call * NN
# 256 * 256 * CD
# eight * eight * CD
# morning * morning * NN
# shall * shall * MD
# clear * clear * VB
# field * field * NN
# besides * besides * NNS
# must * must * MD
# p * p * VB
# ... * ... * :
# 257 * 257 * CD
# reach * reach * NN
# baker * baker * NN
# street * street * NN
# stop * stop * JJ
# door * door * NN
# search * search * NN
# pocket * pocket * NN
# key * key * NN
# ... * ... * :
# 258 * 258 * CD
# good * good * JJ
# night * night * NN
# mister * mister * NN
# sherlock * sherlock * NN
# holme * holme * VBD
# 259 * 259 * CD
# several * several * JJ
# people * people * NNS
# pavement * pavement * JJ
# time * time * NN
# greeting * greeting * VBG
# appear * appear * JJ
# c * c * NNS
# ... * ... * :
# 260 * 260 * CD
# hear * hear * JJ
# voice * voice * NNS
# say * say * VBP
# holme * holme * NNS
# stare * stare * JJ
# dimly * dimly * RB
# light * light * JJ
# street * street * NN
# ... * ... * :
# 261 * 261 * CD
# iii * iii * JJ
# 262 * 262 * CD
# sleep * sleep * JJ
# baker * baker * NN
# street * street * NN
# night * night * NN
# engage * engage * VB
# upon * upon * IN
# toast * toast * NN
# cof * cof * NN
# ... * ... * :
# 263 * 263 * CD
# really * really * RB
# get * get * VB
# cry * cry * JJ
# grasp * grasp * NN
# sherlock * sherlock * NN
# holme * holme * NN
# either * either * CC
# sho * sho * NN
# ... * ... * :
# 264 * 264 * CD
# yet * yet * RB
# 265 * 265 * CD
# hope * hope * NN
# 266 * 266 * CD
# hope * hope * NN
# 267 * 267 * CD
# come * come * NN
# impatience * impatience * NN
# go * go * VBP
# 268 * 268 * CD
# must * must * MD
# cab * cab * VB
# 269 * 269 * CD
# brougham * brougham * NN
# wait * wait * NN
# 270 * 270 * CD
# simplify * simplify * JJ
# matter * matter * NN
# descend * descend * VBP
# start * start * NN
# briony * briony * NN
# lodge * lodge * NN
# 271 * 271 * CD
# irene * irene * NN
# adler * adler * NN
# marry * marry * NN
# remark * remark * NN
# holme * holme * VBD
# 272 * 272 * CD
# married * married * VBD
# 273 * 273 * CD
# yesterday * yesterday * NN
# 274 * 274 * CD
# 275 * 275 * CD
# english * english * JJ
# lawyer * lawyer * NN
# name * name * NN
# norton * norton * VBZ
# 276 * 276 * CD
# could * could * MD
# love * love * VB
# 277 * 277 * CD
# hope * hope * NN
# 278 * 278 * CD
# hope * hope * NN
# 279 * 279 * CD
# would * would * MD
# spare * spare * VB
# majesty * majesty * JJ
# fear * fear * NN
# future * future * JJ
# annoyance * annoyance * NN
# lady * lady * NN
# ... * ... * :
# 280 * 280 * CD
# true * true * JJ
# yet * yet * RB
# well * well * RB
# wish * wish * JJ
# station * station * NN
# queen * queen * NN
# would * would * MD
# make * make * VB
# re * re * NN
# ... * ... * :
# 281 * 281 * CD
# door * door * NN
# briony * briony * NN
# lodge * lodge * NN
# open * open * JJ
# elderly * elderly * JJ
# woman * woman * NN
# stand * stand * VBP
# upo * upo * NN
# ... * ... * :
# 282 * 282 * CD
# mr * mr * NN
# sherlock * sherlock * NN
# holmes * holmes * NNS
# believe * believe * VBP
# say * say * VBP
# 283 * 283 * CD
# mr * mr * JJ
# holmes * holmes * NNS
# answer * answer * VBP
# companion * companion * NN
# look * look * NN
# questioning * questioning * VBG
# ra * ra * NNS
# ... * ... * :
# 284 * 284 * CD
# indeed * indeed * RB
# mistress * mistress * NN
# tell * tell * VB
# likely * likely * RB
# call * call * JJ
# leave * leave * VBP
# morning * morning * NN
# ... * ... * :
# 285 * 285 * CD
# sherlock * sherlock * NN
# holme * holme * NN
# stagger * stagger * NN
# back * back * RB
# white * white * JJ
# chagrin * chagrin * NN
# surp * surp * NN
# ... * ... * :
# 286 * 286 * CD
# never * never * RB
# return * return * VBP
# 287 * 287 * CD
# paper * paper * NN
# ask * ask * NN
# king * king * VBG
# hoarsely * hoarsely * RB
# lose * lose * VB
# 288 * 288 * CD
# shall * shall * MD
# see * see * VB
# push * push * JJ
# past * past * NN
# servant * servant * NN
# rush * rush * NN
# drawing * drawing * VBG
# room * room * NN
# ... * ... * :
# 289 * 289 * CD
# dear * dear * JJ
# mr * mr * NN
# sherlock * sherlock * NN
# holmesyou * holmesyou * NN
# really * really * RB
# well * well * RB
# take * take * VB
# co * co * NN
# ... * ... * :
# 290 * 290 * CD
# well * well * RB
# follow * follow * JJ
# door * door * NN
# make * make * VBP
# sure * sure * JJ
# really * really * RB
# object * object * JJ
# inter * inter * NN
# ... * ... * :
# 291 * 291 * CD
# think * think * VBP
# good * good * JJ
# resource * resource * NN
# flight * flight * NN
# pursue * pursue * NN
# formidable * formidable * VB
# a * a * DT
# ... * ... * :
# 292 * 292 * CD
# truly * truly * RB
# 293 * 293 * CD
# irene * irene * JJ
# norton * norton * NN
# nee * nee * NN
# adler * adler * NN
# 294 * 294 * CD
# woman * woman * NN
# oh * oh * PRP
# woman * woman * NN
# cry * cry * NN
# king * king * VBG
# bohemia * bohemia * NN
# three * three * CD
# read * read * NN
# epi * epi * NN
# ... * ... * :
# 295 * 295 * CD
# see * see * VBP
# lady * lady * JJ
# seem * seem * VBP
# indeed * indeed * RB
# different * different * JJ
# level * level * NN
# majesty * majesty * NN
# s * s * NN
# ... * ... * :
# 296 * 296 * CD
# contrary * contrary * JJ
# dear * dear * NN
# sir * sir * NN
# cry * cry * NN
# king * king * VBG
# nothing * nothing * NN
# could * could * MD
# succe * succe * VB
# ... * ... * :
# 297 * 297 * CD
# glad * glad * JJ
# hear * hear * JJ
# majesty * majesty * NNS
# say * say * VBP
# 298 * 298 * CD
# immensely * immensely * RB
# indebted * indebted * JJ
# pray * pray * NN
# tell * tell * VB
# way * way * NN
# reward * reward * NN
# ring * ring * NN
# s * s * NN
# ... * ... * :
# 299 * 299 * CD
# majesty * majesty * JJ
# something * something * NN
# value * value * NN
# even * even * RB
# highly * highly * RB
# say * say * VBP
# holme * holme * UH
# 300 * 300 * CD
# name * name * NN
# 301 * 301 * CD
# photograph * photograph * NN
# 302 * 302 * CD
# king * king * NN
# stare * stare * NN
# amazement * amazement * JJ
# 303 * 303 * CD
# irene * irene * NN
# photograph * photograph * NN
# cry * cry * NN
# certainly * certainly * RB
# wish * wish * JJ
# 304 * 304 * CD
# thank * thank * NN
# majesty * majesty * JJ
# matter * matter * NN
# honour * honour * PRP$
# wish * wish * JJ
# good * good * JJ
# morning * morning * NN
# ... * ... * :
# 305 * 305 * CD
# great * great * JJ
# scandal * scandal * NN
# threaten * threaten * NN
# affect * affect * JJ
# kingdom * kingdom * NN
# bohemia * bohemia * NN
# ... * ... * :
# 306 * 306 * CD
# adventure * adventure * NN
# ii * ii * NN
# red * red * JJ
# head * head * NN
# league * league * NN
# 307 * 307 * CD
# call * call * NN
# upon * upon * IN
# friend * friend * NN
# mr * mr * NN
# sherlock * sherlock * NN
# holmes * holmes * NNS
# one * one * CD
# day * day * NN
# au * au * VBD
# ... * ... * :
# 308 * 308 * CD
# could * could * MD
# possibly * possibly * RB
# come * come * VB
# well * well * RB
# time * time * NN
# dear * dear * JJ
# watson * watson * NNS
# say * say * VBP
# ... * ... * :
# 309 * 309 * CD
# afraid * afraid * JJ
# engage * engage * NN
# 310 * 310 * CD
# much * much * RB
# 311 * 311 * CD
# wait * wait * JJ
# next * next * JJ
# room * room * NN
# 312 * 312 * CD
# gentleman * gentleman * NN
# mr * mr * NN
# wilson * wilson * NN
# partner * partner * NN
# helper * helper * VBD
# many * many * JJ
# succes * succes * NNS
# ... * ... * :
# 313 * 313 * CD
# stout * stout * NN
# gentleman * gentleman * NN
# half * half * NN
# rise * rise * NN
# chair * chair * NN
# give * give * VBP
# bob * bob * NN
# greet * greet * NN
# ... * ... * :
# 314 * 314 * CD
# try * try * NN
# settee * settee * NNS
# say * say * VBP
# holme * holme * JJ
# relapse * relapse * NN
# armchair * armchair * NN
# put * put * VBD
# fing * fing * VBG
# ... * ... * :
# 315 * 315 * CD
# case * case * NN
# indeed * indeed * RB
# great * great * JJ
# interest * interest * NN
# observe * observe * NN
# 316 * 316 * CD
# remember * remember * JJ
# remark * remark * NN
# day * day * NN
# go * go * VBP
# simple * simple * JJ
# problem * problem * NN
# present * present * NN
# ... * ... * :
# 317 * 317 * CD
# proposition * proposition * NN
# take * take * VB
# liberty * liberty * JJ
# doubt * doubt * NN
# 318 * 318 * CD
# doctor * doctor * NN
# none * none * NN
# less * le * JJR
# must * must * MD
# come * come * VB
# round * round * NN
# view * view * NN
# otherwis * otherwis * VBP
# ... * ... * :
# 319 * 319 * CD
# portly * portly * RB
# client * client * NN
# puff * puff * NN
# chest * chest * JJS
# appearance * appearance * NN
# little * little * JJ
# pri * pri * NN
# ... * ... * :
# 320 * 320 * CD
# gain * gain * NN
# much * much * JJ
# however * however * RB
# inspection * inspection * NN
# visitor * visitor * NN
# bore * bore * VBD
# ever * ever * RB
# ... * ... * :
# 321 * 321 * CD
# sherlock * sherlock * NN
# holme * holme * NN
# quick * quick * JJ
# eye * eye * NN
# take * take * VB
# occupation * occupation * NN
# shake * shake * NN
# ... * ... * :
# 322 * 322 * CD
# mr * mr * NN
# jabez * jabez * NN
# wilson * wilson * JJ
# start * start * NN
# chair * chair * NN
# forefinger * forefinger * NN
# upon * upon * IN
# pa * pa * NN
# ... * ... * :
# 323 * 323 * CD
# name * name * NN
# good * good * JJ
# fortune * fortune * NN
# know * know * VBP
# mr * mr * NN
# holmes * holmes * NNS
# ask * ask * VBP
# know * know * VBP
# exam * exam * NN
# ... * ... * :
# 324 * 324 * CD
# hand * hand * NN
# dear * dear * NN
# sir * sir * NN
# right * right * JJ
# hand * hand * NN
# quite * quite * RB
# size * size * NN
# large * large * JJ
# left * left * VBD
# ... * ... * :
# 325 * 325 * CD
# well * well * RB
# snuff * snuff * JJ
# freemasonry * freemasonry * NN
# 326 * 326 * CD
# insult * insult * NN
# intelligence * intelligence * NN
# tell * tell * VBP
# read * read * VBN
# especially * especially * RB
# rathe * rathe * VBP
# ... * ... * :
# 327 * 327 * CD
# ah * ah * JJ
# course * course * NN
# forget * forget * NN
# writing * writing * VBG
# 328 * 328 * CD
# else * else * JJ
# indicate * indicate * NN
# right * right * NN
# cuff * cuff * NN
# shiny * shiny * JJ
# five * five * CD
# inch * inch * NN
# left * left * VBD
# ... * ... * :
# 329 * 329 * CD
# well * well * RB
# china * china * RB
# 330 * 330 * CD
# fish * fish * JJ
# tattoo * tattoo * NN
# immediately * immediately * RB
# right * right * JJ
# wrist * wrist * NN
# could * could * MD
# chin * chin * VB
# ... * ... * :
# 331 * 331 * CD
# mr * mr * NN
# jabez * jabez * NN
# wilson * wilson * NN
# laugh * laugh * IN
# heavily * heavily * RB
# well * well * RB
# never * never * RB
# say * say * VBP
# t * t * NNS
# ... * ... * :
# 332 * 332 * CD
# begin * begin * NN
# think * think * VBP
# watson * watson * IN
# say * say * VBP
# holme * holme * NNS
# make * make * VBP
# mistake * mistake * NN
# expl * expl * NN
# ... * ... * :
# 333 * 333 * CD
# yes * yes * NNS
# get * get * VBP
# answer * answer * JJR
# thick * thick * NN
# red * red * JJ
# finger * finger * NN
# plant * plant * NN
# halfway * halfway * NN
# ... * ... * :
# 334 * 334 * CD
# take * take * VBP
# paper * paper * NN
# read * read * VBN
# follow * follow * JJ
# 335 * 335 * CD
# red * red * JJ
# headed * headed * VBD
# league * league * NN
# account * account * NN
# bequest * bequest * JJS
# late * late * JJ
# ezekiah * ezekiah * NN
# ... * ... * :
# 336 * 336 * CD
# earth * earth * JJ
# mean * mean * JJ
# ejaculate * ejaculate * NN
# twice * twice * RB
# read * read * VBD
# extraordinary * extraordinary * JJ
# ... * ... * :
# 337 * 337 * CD
# holme * holme * NN
# chuckle * chuckle * NN
# wriggle * wriggle * VBP
# chair * chair * NN
# habit * habit * NN
# high * high * JJ
# spirit * spirit * NN
# ... * ... * :
# 338 * 338 * CD
# morning * morning * NN
# chronicle * chronicle * NN
# april * april * RB
# two * two * CD
# month * month * NN
# ago * ago * IN
# 339 * 339 * CD
# good * good * JJ
# mr * mr * NN
# wilson * wilson * NN
# 340 * 340 * CD
# well * well * RB
# tell * tell * VB
# mr * mr * NN
# sherlock * sherlock * NN
# holmes * holmes * NNS
# say * say * VBP
# jabez * jabez * NN
# wilson * wilson * NN
# ... * ... * :
# 341 * 341 * CD
# name * name * NN
# oblige * oblige * JJ
# youth * youth * NN
# ask * ask * NN
# sherlock * sherlock * NN
# holme * holme * NN
# 342 * 342 * CD
# name * name * NN
# vincent * vincent * NN
# spaulding * spaulding * VBG
# youth * youth * NN
# either * either * DT
# hard * hard * JJ
# say * say * VBP
# a * a * DT
# ... * ... * :
# 343 * 343 * CD
# indeed * indeed * RB
# seem * seem * VBP
# fortunate * fortunate * JJ
# employe * employe * NN
# come * come * VBP
# full * full * JJ
# market * market * NN
# ... * ... * :
# 344 * 344 * CD
# oh * oh * IN
# fault * fault * NNS
# say * say * VBP
# mr * mr * JJ
# wilson * wilson * NN
# never * never * RB
# fellow * fellow * JJ
# photograph * photograph * NN
# ... * ... * :
# 345 * 345 * CD
# still * still * RB
# presume * presume * JJ
# 346 * 346 * CD
# yes * yes * NNS
# sir * sir * JJ
# girl * girl * NN
# fourteen * fourteen * JJ
# bit * bit * RB
# simple * simple * JJ
# cooking * cooking * VBG
# keep * keep * NN
# ... * ... * :
# 347 * 347 * CD
# first * first * JJ
# thing * thing * NN
# put * put * VBD
# advertisement * advertisement * JJ
# spaulde * spaulde * NN
# come * come * VB
# off * off * IN
# ... * ... * :
# 348 * 348 * CD
# wish * wish * JJ
# lord * lord * NN
# mr * mr * NN
# wilson * wilson * NN
# red * red * VBD
# headed * headed * VBN
# man * man * NN
# 349 * 349 * CD
# ask * ask * JJ
# 350 * 350 * CD
# say * say * VBP
# another * another * DT
# vacancy * vacancy * NN
# league * league * NN
# red * red * VBD
# headed * headed * VBN
# man * man * NN
# wort * wort * NN
# ... * ... * :
# 351 * 351 * CD
# ask * ask * NN
# see * see * NN
# mr * mr * NN
# holmes * holmes * NNS
# stay * stay * VBP
# home * home * RB
# man * man * NN
# business * business * NN
# come * come * VBD
# ... * ... * :
# 352 * 352 * CD
# never * never * RB
# hear * hear * VBP
# league * league * NN
# red * red * JJ
# headed * headed * VBD
# man * man * NN
# ask * ask * NN
# eye * eye * NN
# open * open * JJ
# 353 * 353 * CD
# never * never * RB
# 354 * 354 * CD
# wonder * wonder * NN
# eligible * eligible * JJ
# one * one * CD
# vacancy * vacancy * NN
# 355 * 355 * CD
# worth * worth * NN
# ask * ask * RB
# 356 * 356 * CD
# oh * oh * NNS
# merely * merely * RB
# couple * couple * VBP
# hundred * hundred * CD
# year * year * NN
# work * work * NN
# slight * slight * VBD
# need * need * NN
# ... * ... * :
# 357 * 357 * CD
# well * well * RB
# easily * easily * RB
# think * think * VBP
# make * make * VBP
# prick * prick * JJ
# ear * ear * NN
# business * business * NN
# good * good * VBD
# ... * ... * :
# 358 * 358 * CD
# tell * tell * NNS
# say * say * VBP
# 359 * 359 * CD
# well * well * RB
# say * say * VB
# show * show * NN
# advertisement * advertisement * JJ
# see * see * NN
# league * league * JJ
# vacancy * vacancy * NN
# ... * ... * :
# 360 * 360 * CD
# say * say * VBP
# would * would * MD
# million * million * CD
# red * red * JJ
# head * head * NN
# man * man * NN
# would * would * MD
# apply * apply * VB
# 361 * 361 * CD
# many * many * JJ
# might * might * MD
# think * think * VB
# answer * answer * JJR
# see * see * NN
# really * really * RB
# confine * confine * VB
# lon * lon * NN
# ... * ... * :
# 362 * 362 * CD
# fact * fact * NN
# gentleman * gentleman * NN
# may * may * MD
# see * see * VB
# hair * hair * JJ
# full * full * JJ
# rich * rich * JJ
# tint * tint * NN
# see * see * VBP
# ... * ... * :
# 363 * 363 * CD
# never * never * RB
# hope * hope * VBP
# see * see * VB
# sight * sight * JJ
# mr * mr * NNS
# holmes * holmes * NNS
# north * north * RB
# south * south * JJ
# eas * ea * NNS
# ... * ... * :
# 364 * 364 * CD
# experience * experience * NN
# entertaining * entertaining * VBG
# one * one * CD
# remark * remark * NN
# holme * holme * NN
# clien * clien * NN
# ... * ... * :
# 365 * 365 * CD
# nothing * nothing * NN
# office * office * NN
# couple * couple * NN
# wooden * wooden * VBP
# chair * chair * NN
# deal * deal * NN
# table * table * NN
# ... * ... * :
# 366 * 366 * CD
# mr * mr * NN
# jabez * jabez * NN
# wilson * wilson * NN
# say * say * VBP
# assistant * assistant * NN
# willing * willing * JJ
# fill * fill * NN
# vac * vac * NN
# ... * ... * :
# 367 * 367 * CD
# admirably * admirably * RB
# suit * suit * NN
# answer * answer * NN
# every * every * DT
# requirement * requirement * NN
# recall * recall * NN
# ... * ... * :
# 368 * 368 * CD
# would * would * MD
# injustice * injustice * VB
# hesitate * hesitate * NN
# say * say * VBP
# however * however * RB
# sure * sure * JJ
# excu * excu * VBP
# ... * ... * :
# 369 * 369 * CD
# name * name * NNS
# say * say * VBP
# mr * mr * JJ
# duncan * duncan * JJ
# ross * ross * NN
# one * one * CD
# pensioner * pensioner * NN
# upon * upon * IN
# fun * fun * NN
# ... * ... * :
# 370 * 370 * CD
# answer * answer * NN
# 371 * 371 * CD
# face * face * NN
# fall * fall * NN
# immediately * immediately * RB
# 372 * 372 * CD
# dear * dear * JJ
# say * say * VBP
# gravely * gravely * RB
# serious * serious * JJ
# indeed * indeed * RB
# sorry * sorry * JJ
# hear * hear * VBP
# say * say * VBP
# ... * ... * :
# 373 * 373 * CD
# face * face * NN
# lengthen * lengthen * NN
# mr * mr * VBD
# holmes * holmes * NNS
# think * think * VBP
# vacancy * vacancy * NN
# think * think * VBP
# mi * mi * NN
# ... * ... * :
# 374 * 374 * CD
# case * case * NN
# another * another * DT
# say * say * VBP
# objection * objection * NN
# might * might * MD
# fatal * fatal * VB
# must * must * MD
# st * st * VB
# ... * ... * :
# 375 * 375 * CD
# well * well * RB
# little * little * JJ
# awkward * awkward * JJ
# business * business * NN
# already * already * RB
# say * say * VB
# 376 * 376 * CD
# oh * oh * JJ
# never * never * RB
# mind * mind * VBP
# mr * mr * JJ
# wilson * wilson * NNS
# say * say * VBP
# vincent * vincent * JJ
# spaulding * spaulding * NN
# ... * ... * :
# 377 * 377 * CD
# would * would * MD
# hour * hour * NN
# ask * ask * VB
# 378 * 378 * CD
# ten * ten * CD
# two * two * CD
# 379 * 379 * CD
# pawnbroker * pawnbroker * NN
# business * business * NN
# mostly * mostly * RB
# evening * evening * VBG
# mr * mr * NN
# holmes * holmes * NNS
# e * e * VBP
# ... * ... * :
# 380 * 380 * CD
# would * would * MD
# suit * suit * VB
# well * well * RB
# say * say * VB
# pay * pay * NN
# 381 * 381 * CD
# week * week * NN
# 382 * 382 * CD
# work * work * NN
# 383 * 383 * CD
# purely * purely * RB
# nominal * nominal * JJ
# 384 * 384 * CD
# call * call * NN
# purely * purely * RB
# nominal * nominal * JJ
# 385 * 385 * CD
# well * well * RB
# office * office * NN
# least * least * JJS
# building * building * NN
# whole * whole * JJ
# time * time * NN
# leave * leave * VBP
# fo * fo * NNS
# ... * ... * :
# 386 * 386 * CD
# four * four * CD
# hour * hour * NN
# day * day * NN
# think * think * VBP
# leave * leave * VBP
# say * say * VBP
# 387 * 387 * CD
# excuse * excuse * NN
# avail * avail * NNS
# say * say * VBP
# mr * mr * JJ
# duncan * duncan * JJ
# ross * ross * NN
# neither * neither * CC
# sickne * sickne * NN
# ... * ... * :
# 388 * 388 * CD
# work * work * NN
# 389 * 389 * CD
# copy * copy * NN
# encyclopaedia * encyclopaedia * NN
# britannica * britannica * NN
# first * first * JJ
# volume * volume * NN
# pre * pre * NN
# ... * ... * :
# 390 * 390 * CD
# certainly * certainly * RB
# answer * answer * RB
# 391 * 391 * CD
# good * good * JJ
# bye * bye * NN
# mr * mr * NN
# jabez * jabez * NN
# wilson * wilson * NN
# let * let * VB
# congratulate * congratulate * NN
# impo * impo * NNS
# ... * ... * :
# 392 * 392 * CD
# well * well * RB
# think * think * VBP
# matter * matter * JJR
# day * day * NN
# evening * evening * VBG
# low * low * JJ
# spirit * spirit * NN
# quite * quite * RB
# ... * ... * :
# 393 * 393 * CD
# well * well * RB
# surprise * surprise * VB
# delight * delight * NN
# everything * everything * NN
# right * right * RB
# possibl * possibl * NN
# ... * ... * :
# 394 * 394 * CD
# go * go * JJ
# day * day * NN
# day * day * NN
# mr * mr * VBD
# holmes * holmes * NNS
# saturday * saturday * JJ
# manager * manager * NN
# come * come * VB
# pla * pla * NN
# ... * ... * :
# 395 * 395 * CD
# eight * eight * CD
# week * week * NN
# pass * pas * NN
# away * away * RB
# like * like * IN
# write * write * JJ
# abbot * abbot * JJ
# archery * archery * NN
# ... * ... * :
# 396 * 396 * CD
# end * end * NN
# 397 * 397 * CD
# yes * yes * NNS
# sir * sir * RB
# later * later * RB
# morning * morning * NN
# go * go * VB
# work * work * NN
# usual * usual * JJ
# ten * ten * NN
# oclock * oclock * NN
# ... * ... * :
# 398 * 398 * CD
# hold * hold * JJ
# piece * piece * NN
# white * white * JJ
# cardboard * cardboard * JJ
# size * size * NN
# sheet * sheet * NN
# note * note * NN
# pap * pap * NN
# ... * ... * :
# 399 * 399 * CD
# red * red * JJ
# head * head * NN
# league * league * VBD
# 400 * 400 * CD
# 401 * 401 * CD
# dissolve * dissolve * NN
# 402 * 402 * CD
# october * october * $
# 403 * 403 * CD
# sherlock * sherlock * NN
# holme * holme * NN
# survey * survey * NN
# curt * curt * VBD
# announcement * announcement * NN
# rueful * rueful * NN
# ... * ... * :
# 404 * 404 * CD
# see * see * VBP
# anything * anything * NN
# funny * funny * JJ
# cry * cry * NN
# client * client * NN
# flush * flush * JJ
# root * root * NN
# flame * flame * NN
# ... * ... * :
# 405 * 405 * CD
# cry * cry * NN
# holme * holme * NN
# shove * shove * VB
# back * back * RB
# chair * chair * NN
# half * half * NN
# rise * rise * NN
# really * really * RB
# wo * wo * MD
# ... * ... * :
# 406 * 406 * CD
# stagger * stagger * NN
# sir * sir * NN
# know * know * VBP
# call * call * NN
# ...
# 715 * 715 * CD
# coroner * coroner * NN
# utter * utter * JJ
# see * see * VB
# even * even * RB
# know * know * VB
# return * return * NN
# bristol * bristol * IN
# 716 * 716 * CD
# witness * witness * NN
# considerable * considerable * JJ
# confusion * confusion * NN
# know * know * VBP
# 717 * 717 * CD
# juryman * juryman * JJ
# see * see * NN
# nothing * nothing * NN
# arouse * arouse * IN
# suspicion * suspicion * NN
# return * return * NN
# he * he * PRP
# ... * ... * :
# 718 * 718 * CD
# witness * witness * NN
# nothing * nothing * NN
# definite * definite * JJ
# 719 * 719 * CD
# coroner * coroner * NN
# mean * mean * JJ
# 720 * 720 * CD
# witness * witness * NN
# disturbed * disturbed * VBD
# excited * excited * JJ
# rush * rush * NN
# open * open * VB
# could * could * MD
# thin * thin * VB
# ... * ... * :
# 721 * 721 * CD
# mean * mean * JJ
# disappear * disappear * NN
# go * go * VBP
# help * help * NN
# 722 * 722 * CD
# yes * yes * NNS
# go * go * VBP
# 723 * 723 * CD
# say * say * VBP
# 724 * 724 * CD
# feeling * feeling * VBG
# something * something * NN
# 725 * 725 * CD
# far * far * RB
# body * body * NN
# 726 * 726 * CD
# dozen * dozen * NN
# yard * yard * NN
# 727 * 727 * CD
# far * far * RB
# edge * edge * JJ
# wood * wood * NN
# 728 * 728 * CD
# 729 * 729 * CD
# remove * remove * NN
# within * within * IN
# dozen * dozen * NN
# yard * yard * RB
# 730 * 730 * CD
# yes * yes * NNS
# back * back * RB
# towards * towards * IN
# 731 * 731 * CD
# conclude * conclude * NN
# examination * examination * NN
# witness * witness * NN
# 732 * 732 * CD
# see * see * NNS
# say * say * VBP
# glance * glance * NN
# column * column * NN
# coroner * coroner * NN
# concluding * concluding * VBG
# remar * remar * NN
# ... * ... * :
# 733 * 733 * CD
# holme * holme * NN
# laugh * laugh * NN
# softly * softly * RB
# stretch * stretch * VBZ
# upon * upon * IN
# cushion * cushion * NN
# seat * seat * NN
# c * c * NNS
# ... * ... * :
# 734 * 734 * CD
# nearly * nearly * RB
# four * four * CD
# oclock * oclock * NN
# last * last * JJ
# pass * pas * NN
# beautiful * beautiful * JJ
# stroud * stroud * NN
# ... * ... * :
# 735 * 735 * CD
# order * order * NN
# carriage * carriage * NN
# say * say * VBP
# lestrade * lestrade * VBN
# sit * sit * JJ
# cup * cup * NN
# tea * tea * NN
# know * know * VBP
# e * e * NN
# ... * ... * :
# 736 * 736 * CD
# nice * nice * JJ
# complimentary * complimentary * JJ
# holme * holme * NN
# answer * answer * NN
# entirely * entirely * RB
# quest * quest * JJS
# ... * ... * :
# 737 * 737 * CD
# lestrade * lestrade * JJ
# look * look * NN
# startle * startle * JJ
# quite * quite * RB
# follow * follow * VBP
# say * say * VBP
# 738 * 738 * CD
# glass * glass * NN
# twenty * twenty * NN
# nine * nine * CD
# see * see * NN
# wind * wind * IN
# cloud * cloud * JJ
# sky * sky * JJ
# caseful * caseful * JJ
# c * c * NN
# ... * ... * :
# 739 * 739 * CD
# lestrade * lestrade * JJ
# laugh * laugh * NN
# indulgently * indulgently * RB
# doubt * doubt * VB
# already * already * RB
# form * form * VB
# ... * ... * :
# 740 * 740 * CD
# hardly * hardly * RB
# speak * speak * JJ
# rush * rush * NN
# room * room * NN
# one * one * CD
# lovely * lovely * RB
# young * young * JJ
# woman * woman * NN
# ... * ... * :
# 741 * 741 * CD
# oh * oh * JJ
# mr * mr * NN
# sherlock * sherlock * NN
# holme * holme * NN
# cry * cry * NN
# glance * glance * NN
# one * one * CD
# finally * finally * RB
# wo * wo * MD
# ... * ... * :
# 742 * 742 * CD
# hope * hope * NN
# may * may * MD
# clear * clear * VB
# miss * miss * JJ
# turner * turner * NNS
# say * say * VBP
# sherlock * sherlock * NN
# holme * holme * NN
# ... * ... * :
# 743 * 743 * CD
# read * read * JJ
# evidence * evidence * NN
# form * form * JJ
# conclusion * conclusion * NN
# see * see * VBP
# loophole * loophole * JJ
# fla * fla * NN
# ... * ... * :
# 744 * 744 * CD
# think * think * VBP
# probable * probable * JJ
# 745 * 745 * CD
# cry * cry * NN
# throw * throw * NN
# back * back * RB
# head * head * JJ
# look * look * NN
# defiantly * defiantly * RB
# lestrade * lestrade * VBD
# he * he * PRP
# ... * ... * :
# 746 * 746 * CD
# lestrade * lestrade * JJ
# shrug * shrug * NN
# shoulder * shoulder * NN
# afraid * afraid * JJ
# colleague * colleague * NN
# littl * littl * NN
# ... * ... * :
# 747 * 747 * CD
# right * right * JJ
# oh * oh * NN
# know * know * VB
# right * right * JJ
# james * james * NNS
# never * never * RB
# quarrel * quarrel * VBP
# father * father * NN
# ... * ... * :
# 748 * 748 * CD
# way * way * NN
# ask * ask * NN
# holme * holme * VBD
# 749 * 749 * CD
# time * time * NN
# hide * hide * NN
# anything * anything * NN
# james * james * VBZ
# father * father * RB
# many * many * JJ
# disagreem * disagreem * VBP
# ... * ... * :
# 750 * 750 * CD
# father * father * NN
# ask * ask * NN
# holme * holme * VBZ
# favour * favour * CD
# union * union * NN
# 751 * 751 * CD
# averse * averse * NN
# also * also * RB
# one * one * CD
# mr * mr * NN
# mccarthy * mccarthy * FW
# favour * favour * VBP
# quick * quick * JJ
# blush * blush * NN
# ... * ... * :
# 752 * 752 * CD
# thank * thank * JJ
# information * information * NN
# say * say * VBP
# may * may * MD
# see * see * VB
# father * father * JJR
# call * call * NN
# morrow * morrow * NN
# 753 * 753 * CD
# afraid * afraid * JJ
# doctor * doctor * NN
# allow * allow * IN
# 754 * 754 * CD
# doctor * doctor * NN
# 755 * 755 * CD
# yes * yes * NNS
# hear * hear * JJ
# poor * poor * JJ
# father * father * NN
# never * never * RB
# strong * strong * JJ
# year * year * NN
# back * back * RB
# br * br * NN
# ... * ... * :
# 756 * 756 * CD
# ha * ha * NN
# victoria * victoria * NN
# important * important * JJ
# 757 * 757 * CD
# yes * yes * NNS
# mine * mine * JJ
# 758 * 758 * CD
# quite * quite * RB
# gold * gold * JJ
# mine * mine * NN
# understand * understand * NN
# mr * mr * NN
# turner * turner * NN
# make * make * VBP
# money * money * NN
# 759 * 759 * CD
# yes * yes * RB
# certainly * certainly * RB
# 760 * 760 * CD
# thank * thank * JJ
# miss * miss * JJ
# turner * turner * NN
# material * material * JJ
# assistance * assistance * NN
# 761 * 761 * CD
# tell * tell * NN
# news * news * NN
# morrow * morrow * NN
# doubt * doubt * NN
# go * go * VB
# prison * prison * NN
# see * see * NN
# james * james * NNS
# oh * oh * VBP
# ... * ... * :
# 762 * 762 * CD
# miss * miss * JJ
# turner * turner * NN
# 763 * 763 * CD
# must * must * MD
# go * go * VB
# home * home * NN
# dad * dad * NN
# ill * ill * NN
# miss * miss * NNS
# leave * leave * VBP
# good * good * JJ
# bye * bye * NN
# god * god * NN
# h * h * NN
# ... * ... * :
# 764 * 764 * CD
# ashamed * ashamed * JJ
# holme * holme * NNS
# say * say * VBP
# lestrade * lestrade * JJ
# dignity * dignity * NN
# minute * minute * NN
# sile * sile * NN
# ... * ... * :
# 765 * 765 * CD
# think * think * VBP
# see * see * VB
# way * way * NN
# clear * clear * JJ
# james * james * NNS
# mccarthy * mccarthy * JJ
# say * say * VBP
# holme * holme * JJ
# o * o * NN
# ... * ... * :
# 766 * 766 * CD
# yes * yes * NNS
# 767 * 767 * CD
# shall * shall * MD
# reconsider * reconsider * VB
# resolution * resolution * NN
# go * go * VB
# still * still * RB
# time * time * NN
# take * take * VB
# ... * ... * :
# 768 * 768 * CD
# ample * ample * JJ
# 769 * 769 * CD
# let * let * NN
# watson * watson * NN
# fear * fear * VB
# find * find * IN
# slow * slow * JJ
# shall * shall * MD
# away * away * RB
# couple * couple * VB
# hour * hour * NN
# 770 * 770 * CD
# walk * walk * NN
# station * station * NN
# wander * wander * WRB
# street * street * NN
# little * little * JJ
# town * town * NN
# finally * finally * RB
# ... * ... * :
# 771 * 771 * CD
# late * late * JJ
# sherlock * sherlock * NN
# holme * holme * NN
# return * return * NN
# come * come * VBN
# back * back * RB
# alone * alone * JJ
# les * le * NNS
# ... * ... * :
# 772 * 772 * CD
# glass * glass * NN
# still * still * RB
# keep * keep * VB
# high * high * JJ
# remark * remark * NN
# sit * sit * NN
# importance * importance * NN
# ra * ra * NN
# ... * ... * :
# 773 * 773 * CD
# learn * learn * JJ
# 774 * 774 * CD
# nothing * nothing * NN
# 775 * 775 * CD
# could * could * MD
# throw * throw * VB
# light * light * JJ
# 776 * 776 * CD
# none * none * NN
# inclined * inclined * VBD
# think * think * VB
# one * one * CD
# time * time * NN
# know * know * VB
# screen * screen * JJ
# convi * convi * NNS
# ... * ... * :
# 777 * 777 * CD
# admire * admire * NN
# taste * taste * NN
# remark * remark * NN
# indeed * indeed * RB
# fact * fact * NN
# averse * averse * JJ
# marriag * marriag * NN
# ... * ... * :
# 778 * 778 * CD
# ah * ah * NN
# thereby * thereby * RB
# hang * hang * VBD
# rather * rather * RB
# painful * painful * JJ
# tale * tale * JJ
# fellow * fellow * NN
# mad * mad * NN
# ... * ... * :
# 779 * 779 * CD
# innocent * innocent * JJ
# 780 * 780 * CD
# ah * ah * NN
# would * would * MD
# call * call * VB
# attention * attention * NN
# particularly * particularly * RB
# two * two * CD
# point * point * NN
# ... * ... * :
# 781 * 781 * CD
# rain * rain * NN
# holme * holme * NN
# foretold * foretold * VBD
# morning * morning * NN
# break * break * NN
# bright * bright * JJ
# cloud * cloud * NN
# ... * ... * :
# 782 * 782 * CD
# serious * serious * JJ
# news * news * NN
# morning * morning * NN
# lestrade * lestrade * NN
# observe * observe * VBP
# say * say * VBP
# mr * mr * JJ
# t * t * NN
# ... * ... * :
# 783 * 783 * CD
# elderly * elderly * JJ
# man * man * NN
# presume * presume * NNS
# say * say * VBP
# holme * holme * JJ
# 784 * 784 * CD
# sixty * sixty * JJ
# constitution * constitution * NN
# shatter * shatter * NN
# life * life * NN
# abroad * abroad * RB
# fail * fail * VBZ
# he * he * PRP
# ... * ... * :
# 785 * 785 * CD
# indeed * indeed * RB
# interesting * interesting * JJ
# say * say * VBP
# holme * holme * JJ
# 786 * 786 * CD
# oh * oh * JJ
# yes * yes * NNS
# hundred * hundred * VBD
# way * way * NN
# help * help * NN
# everybody * everybody * NN
# speak * speak * VB
# kindness * kindness * JJ
# 787 * 787 * CD
# really * really * RB
# strike * strike * JJ
# little * little * JJ
# singular * singular * JJ
# mccarthy * mccarthy * NN
# appear * appear * VBP
# ... * ... * :
# 788 * 788 * CD
# get * get * NN
# deduction * deduction * NN
# inference * inference * NN
# say * say * VBP
# lestrade * lestrade * VBN
# wink * wink * VBP
# find * find * VBP
# ... * ... * :
# 789 * 789 * CD
# right * right * JJ
# say * say * VBP
# holme * holme * NNS
# demurely * demurely * RB
# find * find * VBP
# hard * hard * JJ
# tackle * tackle * NN
# fact * fact * NN
# 790 * 790 * CD
# anyhow * anyhow * NN
# grasp * grasp * JJ
# one * one * CD
# fact * fact * NN
# seem * seem * VBP
# find * find * VB
# difficult * difficult * JJ
# get * get * NN
# ... * ... * :
# 791 * 791 * CD
# 792 * 792 * CD
# mccarthy * mccarthy * JJ
# senior * senior * JJ
# meet * meet * NN
# death * death * NN
# mccarthy * mccarthy * NN
# junior * junior * VBP
# the * the * DT
# ... * ... * :
# 793 * 793 * CD
# well * well * RB
# moonshine * moonshine * JJ
# bright * bright * JJ
# thing * thing * NN
# fog * fog * NNS
# say * say * VBP
# holme * holme * JJ
# laug * laug * NN
# ... * ... * :
# 794 * 794 * CD
# yes * yes * NNS
# widespread * widespread * JJ
# comfortable * comfortable * JJ
# look * look * NN
# building * building * VBG
# two * two * CD
# s * s * NN
# ... * ... * :
# 795 * 795 * CD
# sherlock * sherlock * NN
# holme * holme * NN
# transform * transform * NN
# hot * hot * JJ
# upon * upon * IN
# scent * scent * JJ
# man * man * NN
# kn * kn * NN
# ... * ... * :
# 796 * 796 * CD
# boscombe * boscombe * JJ
# pool * pool * NN
# little * little * JJ
# reed * reed * JJ
# girt * girt * NN
# sheet * sheet * NN
# water * water * NN
# fif * fif * NN
# ... * ... * :
# 797 * 797 * CD
# go * go * VBP
# pool * pool * NN
# ask * ask * RB
# 798 * 798 * CD
# fish * fish * JJ
# rake * rake * NN
# think * think * NN
# might * might * MD
# weapon * weapon * VB
# trace * trace * NN
# earth * earth * NN
# 799 * 799 * CD
# oh * oh * JJ
# tut * tut * NN
# tut * tut * NN
# time * time * NN
# leave * leave * JJ
# foot * foot * NN
# inward * inward * NN
# twist * twist * NN
# place * place * NN
# ... * ... * :
# 800 * 800 * CD
# case * case * NN
# considerable * considerable * JJ
# interest * interest * NN
# remark * remark * NN
# return * return * NN
# natur * natur * NN
# ... * ... * :
# 801 * 801 * CD
# ten * ten * NNS
# minute * minute * JJ
# regain * regain * VBP
# cab * cab * JJ
# drive * drive * NN
# back * back * RB
# ross * ross * VBZ
# holme * holme * NN
# st * st * NN
# ... * ... * :
# 802 * 802 * CD
# may * may * MD
# interest * interest * NN
# lestrade * lestrade * NN
# remark * remark * NN
# hold * hold * VB
# murder * murder * NN
# 803 * 803 * CD
# see * see * NN
# mark * mark * NN
# 804 * 804 * CD
# none * none * NN
# 805 * 805 * CD
# know * know * VBP
# 806 * 806 * CD
# grass * grass * NN
# grow * grow * NN
# lain * lain * VBP
# day * day * NN
# sign * sign * JJ
# place * place * NN
# whence * whence * NN
# take * take * VB
# cor * cor * NN
# ... * ... * :
# 807 * 807 * CD
# murderer * murderer * NN
# 808 * 808 * CD
# tall * tall * JJ
# man * man * NN
# left * left * VBD
# handed * handed * VBN
# limp * limp * NN
# right * right * NN
# leg * leg * NN
# wear * wear * VBP
# thick * thick * NN
# ... * ... * :
# 809 * 809 * CD
# lestrade * lestrade * JJ
# laugh * laugh * NN
# afraid * afraid * NN
# still * still * RB
# sceptic * sceptic * JJ
# say * say * VBP
# theory * theory * NN
# ... * ... * :
# 810 * 810 * CD
# nous * nous * JJ
# verron * verron * NN
# answer * answer * NN
# holme * holme * NN
# calmly * calmly * NN
# work * work * NN
# method * method * NN
# sh * sh * NN
# ... * ... * :
# 811 * 811 * CD
# leave * leave * JJ
# case * case * NN
# unfinished * unfinished * VBD
# 812 * 812 * CD
# finish * finish * JJ
# 813 * 813 * CD
# mystery * mystery * NN
# 814 * 814 * CD
# solve * solve * NN
# 815 * 815 * CD
# criminal * criminal * JJ
# 816 * 816 * CD
# gentleman * gentleman * NN
# describe * describe * VBD
# 817 * 817 * CD
# 818 * 818 * CD
# surely * surely * RB
# would * would * MD
# difficult * difficult * JJ
# find * find * VB
# populous * populous * JJ
# neighbour * neighbour * NNS
# ... * ... * :
# 819 * 819 * CD
# lestrade * lestrade * JJ
# shrug * shrug * NN
# shoulder * shoulder * NN
# practical * practical * JJ
# man * man * NN
# say * say * VBP
# real * real * JJ
# ... * ... * :
# 820 * 820 * CD
# right * right * JJ
# say * say * VBP
# holme * holme * NNS
# quietly * quietly * RB
# give * give * VBP
# chance * chance * NN
# lodging * lodging * NN
# go * go * VBP
# ... * ... * :
# 821 * 821 * CD
# leave * leave * VBP
# lestrade * lestrade * VBN
# room * room * NN
# drive * drive * NN
# hotel * hotel * NN
# find * find * VBP
# lunch * lunch * JJ
# upo * upo * NN
# ... * ... * :
# 822 * 822 * CD
# look * look * NN
# watson * watson * NNS
# say * say * VBP
# cloth * cloth * JJ
# clear * clear * JJ
# sit * sit * NN
# chair * chair * NN
# let * let * VBD
# prea * prea * NNS
# ... * ... * :
# 823 * 823 * CD
# pray * pray * NN
# 824 * 824 * CD
# well * well * RB
# consider * consider * VB
# case * case * NN
# two * two * CD
# point * point * NN
# young * young * JJ
# mccarthy * mccarthy * NN
# na * na * NN
# ... * ... * :
# 825 * 825 * CD
# cooee * cooee * NN
# 826 * 826 * CD
# well * well * RB
# obviously * obviously * RB
# could * could * MD
# mean * mean * VB
# son * son * NN
# son * son * NN
# far * far * RB
# know * know * JJ
# bri * bri * NN
# ... * ... * :
# 827 * 827 * CD
# rat * rat * NN
# 828 * 828 * CD
# sherlock * sherlock * NN
# holme * holme * NNS
# take * take * VBP
# fold * fold * JJ
# paper * paper * NN
# pocket * pocket * NN
# flatten * flatten * VBD
# ... * ... * :
# 829 * 829 * CD
# arat * arat * NN
# read * read * VBD
# 830 * 830 * CD
# raise * raise * NN
# hand * hand * NN
# 831 * 831 * CD
# ballarat * ballarat * NN
# 832 * 832 * CD
# quite * quite * RB
# word * word * NN
# man * man * NN
# utter * utter * JJ
# son * son * NN
# catch * catch * NN
# last * last * JJ
# two * two * CD
# syllab * syllab * NN
# ... * ... * :
# 833 * 833 * CD
# wonderful * wonderful * JJ
# exclaim * exclaim * NN
# 834 * 834 * CD
# obvious * obvious * JJ
# see * see * NN
# narrow * narrow * JJ
# field * field * NN
# considerably * considerably * RB
# possessi * possessi * VBD
# ... * ... * :
# 835 * 835 * CD
# certainly * certainly * RB
# 836 * 836 * CD
# one * one * CD
# home * home * NN
# district * district * NN
# pool * pool * NN
# approach * approach * NN
# farm * farm * NN
# estate * estate * NN
# st * st * NN
# ... * ... * :
# 837 * 837 * CD
# quite * quite * RB
# 838 * 838 * CD
# come * come * JJ
# expedition * expedition * NN
# day * day * NN
# examination * examination * NN
# ground * ground * NN
# gain * gain * NN
# tr * tr * NN
# ... * ... * :
# 839 * 839 * CD
# gain * gain * NN
# 840 * 840 * CD
# know * know * JJ
# method * method * NN
# found * found * VBD
# upon * upon * IN
# observation * observation * NN
# trifle * trifle * RB
# 841 * 841 * CD
# height * height * NN
# know * know * NN
# might * might * MD
# roughly * roughly * RB
# judge * judge * VB
# length * length * NN
# stride * stride * NN
# ... * ... * :
# 842 * 842 * CD
# yes * yes * NNS
# peculiar * peculiar * JJ
# boot * boot * NN
# 843 * 843 * CD
# lameness * lameness * NN
# 844 * 844 * CD
# impression * impression * NN
# right * right * JJ
# foot * foot * NN
# always * always * RB
# less * le * RBR
# distinct * distinct * JJ
# lef * lef * NN
# ... * ... * :
# 845 * 845 * CD
# left * left * VBD
# handedness * handedness * NN
